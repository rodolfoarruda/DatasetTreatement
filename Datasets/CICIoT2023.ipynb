# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import gc
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression

# %%
def dados_tratar(df):
    # Classificar os ataques diretamente e criar uma nova coluna
    DDoS_attacks = ['DDoS-RSTFINFlood','DDoS-PSHACK_Flood','DDoS-SYN_Flood','DDoS-UDP_Flood','DDoS-TCP_Flood','DDoS-ICMP_Flood','DDoS-SynonymousIP_Flood','DDoS-ACK_Fragmentation','DDoS-UDP_Fragmentation','DDoS-ICMP_Fragmentation','DDoS-SlowLoris','DDoS-HTTP_Flood']
    DoS_attacks = ['DoS-UDP_Flood','DoS-SYN_Flood','DoS-TCP_Flood','DoS-HTTP_Flood']
    Mirai_attacks = ['Mirai-greeth_flood','Mirai-greip_flood','Mirai-udpplain']
    Recon_attacks = ['Recon-PingSweep','Recon-OSScan','Recon-PortScan','VulnerabilityScan','Recon-HostDiscovery']
    Spoofing_attacks = ['DNS_Spoofing','MITM-ArpSpoofing']
    Web_attacks = ['BrowserHijacking','Backdoor_Malware','XSS','Uploading_Attack','SqlInjection','CommandInjection']
    BruteForce_attacks = ['DictionaryBruteForce']

    df['attack_cat'] = 'Normal'  # Inicialmente, todos os ataques são classificados como "Normal"
    df.loc[df['label'].isin(DDoS_attacks), 'attack_cat'] = 'DDoS'
    df.loc[df['label'].isin(DoS_attacks), 'attack_cat'] = 'DoS'
    df.loc[df['label'].isin(Mirai_attacks), 'attack_cat'] = 'Mirai'
    df.loc[df['label'].isin(Recon_attacks), 'attack_cat'] = 'Recon'
    df.loc[df['label'].isin(Spoofing_attacks), 'attack_cat'] = 'Spoofing'
    df.loc[df['label'].isin(Web_attacks), 'attack_cat'] = 'Web'
    df.loc[df['label'].isin(BruteForce_attacks), 'attack_cat'] = 'BruteForce'

    #df = df.drop(['label'], axis=1)

    return df


if __name__ == "__main__":
    # Obtém a hora atual antes da execução do programa
    pd.set_option('display.max_columns', None)
    print("Loading dataset...")
    #Load Data
    # Directory containing the files
    directory = '/content/drive/MyDrive/intrusion/ciciot2023/01-RawDataset'

    all_sampled_data = []  # List to store sampled dataframes

    # Get a sorted list of CSV filenames
    csv_files = sorted([f for f in os.listdir(directory) if f.endswith(".csv")])

    for i, filename in enumerate(csv_files, start=1):
      filepath = os.path.join(directory, filename)
      df = pd.read_csv(filepath)
      print(f"Tamanho df: {df.shape}")
      sampled_df = df.sample(frac=0.05)
      print(f"Tamanho sampled_df: {sampled_df.shape}")
      del df
      gc.collect()
      all_sampled_data.append(sampled_df)
      print(f"{i}. Processed: {filename}")

    # Concatenate all sampled dataframes
    concatenated_df = pd.concat(all_sampled_data)
    # Now you can work with the 'concatenated_df'
    print(f'Dados importados com shape: {concatenated_df.shape}')
    df  = dados_tratar(concatenated_df)
    print("Distribuição do label:")
    print(df['label'].value_counts())
    print(f'Dados para AL com shape: {df.shape}')
    print("Salvar dataset")
    df.drop(['label','attack_cat'], axis=1).to_csv('/content/drive/MyDrive/intrusion/ciciot2023/02-TreatedDataset/CICIoT2023_features.csv', index=False,header=False )
    df["attack_cat"].to_csv('/content/drive/MyDrive/intrusion/ciciot2023/02-TreatedDataset/CICIoT2023_8_labels.csv', index=False,header=False )
    df["label"].to_csv('/content/drive/MyDrive/intrusion/ciciot2023/02-TreatedDataset/CICIoT2023_34_labels.csv', index=False,header=False )
    print("Salvar dataset... DONE")
# Out:
# Loading dataset...
# Tamanho df: (238687, 47)
# Tamanho sampled_df: (11934, 47)
# 1. Processed: part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (218805, 47)
# Tamanho sampled_df: (10940, 47)
# 2. Processed: part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (275258, 47)
# Tamanho sampled_df: (13763, 47)
# 3. Processed: part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (231023, 47)
# Tamanho sampled_df: (11551, 47)
# 4. Processed: part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (227491, 47)
# Tamanho sampled_df: (11375, 47)
# 5. Processed: part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (240046, 47)
# Tamanho sampled_df: (12002, 47)
# 6. Processed: part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (233793, 47)
# Tamanho sampled_df: (11690, 47)
# 7. Processed: part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (227910, 47)
# Tamanho sampled_df: (11396, 47)
# 8. Processed: part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (246327, 47)
# Tamanho sampled_df: (12316, 47)
# 9. Processed: part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (227616, 47)
# Tamanho sampled_df: (11381, 47)
# 10. Processed: part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (251392, 47)
# Tamanho sampled_df: (12570, 47)
# 11. Processed: part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (221928, 47)
# Tamanho sampled_df: (11096, 47)
# 12. Processed: part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (238476, 47)
# Tamanho sampled_df: (11924, 47)
# 13. Processed: part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (238761, 47)
# Tamanho sampled_df: (11938, 47)
# 14. Processed: part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (215838, 47)
# Tamanho sampled_df: (10792, 47)
# 15. Processed: part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (268649, 47)
# Tamanho sampled_df: (13432, 47)
# 16. Processed: part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (232885, 47)
# Tamanho sampled_df: (11644, 47)
# 17. Processed: part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (223444, 47)
# Tamanho sampled_df: (11172, 47)
# 18. Processed: part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (234430, 47)
# Tamanho sampled_df: (11722, 47)
# 19. Processed: part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (231063, 47)
# Tamanho sampled_df: (11553, 47)
# 20. Processed: part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (237151, 47)
# Tamanho sampled_df: (11858, 47)
# 21. Processed: part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (223401, 47)
# Tamanho sampled_df: (11170, 47)
# 22. Processed: part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (252212, 47)
# Tamanho sampled_df: (12611, 47)
# 23. Processed: part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (262062, 47)
# Tamanho sampled_df: (13103, 47)
# 24. Processed: part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (225725, 47)
# Tamanho sampled_df: (11286, 47)
# 25. Processed: part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (447625, 47)
# Tamanho sampled_df: (22381, 47)
# 26. Processed: part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (236152, 47)
# Tamanho sampled_df: (11808, 47)
# 27. Processed: part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (221014, 47)
# Tamanho sampled_df: (11051, 47)
# 28. Processed: part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (251225, 47)
# Tamanho sampled_df: (12561, 47)
# 29. Processed: part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (251676, 47)
# Tamanho sampled_df: (12584, 47)
# 30. Processed: part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (238350, 47)
# Tamanho sampled_df: (11918, 47)
# 31. Processed: part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (228730, 47)
# Tamanho sampled_df: (11436, 47)
# 32. Processed: part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (227636, 47)
# Tamanho sampled_df: (11382, 47)
# 33. Processed: part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (447774, 47)
# Tamanho sampled_df: (22389, 47)
# 34. Processed: part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (232228, 47)
# Tamanho sampled_df: (11611, 47)
# 35. Processed: part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (252744, 47)
# Tamanho sampled_df: (12637, 47)
# 36. Processed: part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (439212, 47)
# Tamanho sampled_df: (21961, 47)
# 37. Processed: part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (214963, 47)
# Tamanho sampled_df: (10748, 47)
# 38. Processed: part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (236660, 47)
# Tamanho sampled_df: (11833, 47)
# 39. Processed: part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (437362, 47)
# Tamanho sampled_df: (21868, 47)
# 40. Processed: part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (230365, 47)
# Tamanho sampled_df: (11518, 47)
# 41. Processed: part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (445281, 47)
# Tamanho sampled_df: (22264, 47)
# 42. Processed: part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (222425, 47)
# Tamanho sampled_df: (11121, 47)
# 43. Processed: part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (250954, 47)
# Tamanho sampled_df: (12548, 47)
# 44. Processed: part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (231980, 47)
# Tamanho sampled_df: (11599, 47)
# 45. Processed: part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (247290, 47)
# Tamanho sampled_df: (12364, 47)
# 46. Processed: part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (235566, 47)
# Tamanho sampled_df: (11778, 47)
# 47. Processed: part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239086, 47)
# Tamanho sampled_df: (11954, 47)
# 48. Processed: part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (219877, 47)
# Tamanho sampled_df: (10994, 47)
# 49. Processed: part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (248997, 47)
# Tamanho sampled_df: (12450, 47)
# 50. Processed: part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (233625, 47)
# Tamanho sampled_df: (11681, 47)
# 51. Processed: part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (251256, 47)
# Tamanho sampled_df: (12563, 47)
# 52. Processed: part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (445425, 47)
# Tamanho sampled_df: (22271, 47)
# 53. Processed: part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (243279, 47)
# Tamanho sampled_df: (12164, 47)
# 54. Processed: part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (235625, 47)
# Tamanho sampled_df: (11781, 47)
# 55. Processed: part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (235026, 47)
# Tamanho sampled_df: (11751, 47)
# 57. Processed: part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (429585, 47)
# Tamanho sampled_df: (21479, 47)
# 58. Processed: part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (236995, 47)
# Tamanho sampled_df: (11850, 47)
# 59. Processed: part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (245184, 47)
# Tamanho sampled_df: (12259, 47)
# 60. Processed: part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (254147, 47)
# Tamanho sampled_df: (12707, 47)
# 61. Processed: part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239643, 47)
# Tamanho sampled_df: (11982, 47)
# 62. Processed: part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (441027, 47)
# Tamanho sampled_df: (22051, 47)
# 63. Processed: part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (237426, 47)
# Tamanho sampled_df: (11871, 47)
# 64. Processed: part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (263065, 47)
# Tamanho sampled_df: (13153, 47)
# 65. Processed: part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (244926, 47)
# Tamanho sampled_df: (12246, 47)
# 66. Processed: part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (216084, 47)
# Tamanho sampled_df: (10804, 47)
# 67. Processed: part-00066-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (267928, 47)
# Tamanho sampled_df: (13396, 47)
# 68. Processed: part-00067-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (224089, 47)
# Tamanho sampled_df: (11204, 47)
# 69. Processed: part-00068-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (240206, 47)
# Tamanho sampled_df: (12010, 47)
# 70. Processed: part-00069-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (229776, 47)
# Tamanho sampled_df: (11489, 47)
# 71. Processed: part-00070-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (277720, 47)
# Tamanho sampled_df: (13886, 47)
# 72. Processed: part-00071-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (260695, 47)
# Tamanho sampled_df: (13035, 47)
# 73. Processed: part-00072-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (235721, 47)
# Tamanho sampled_df: (11786, 47)
# 74. Processed: part-00073-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (247037, 47)
# Tamanho sampled_df: (12352, 47)
# 75. Processed: part-00074-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (444334, 47)
# Tamanho sampled_df: (22217, 47)
# 76. Processed: part-00075-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (446795, 47)
# Tamanho sampled_df: (22340, 47)
# 77. Processed: part-00076-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (435700, 47)
# Tamanho sampled_df: (21785, 47)
# 78. Processed: part-00077-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (434834, 47)
# Tamanho sampled_df: (21742, 47)
# 79. Processed: part-00078-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (451034, 47)
# Tamanho sampled_df: (22552, 47)
# 80. Processed: part-00079-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (235689, 47)
# Tamanho sampled_df: (11784, 47)
# 81. Processed: part-00080-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (230739, 47)
# Tamanho sampled_df: (11537, 47)
# 82. Processed: part-00081-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (230193, 47)
# Tamanho sampled_df: (11510, 47)
# 83. Processed: part-00082-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (228653, 47)
# Tamanho sampled_df: (11433, 47)
# 84. Processed: part-00083-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (224827, 47)
# Tamanho sampled_df: (11241, 47)
# 85. Processed: part-00084-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (242969, 47)
# Tamanho sampled_df: (12148, 47)
# 86. Processed: part-00085-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (243026, 47)
# Tamanho sampled_df: (12151, 47)
# 87. Processed: part-00086-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (236324, 47)
# Tamanho sampled_df: (11816, 47)
# 88. Processed: part-00087-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (226970, 47)
# Tamanho sampled_df: (11348, 47)
# 89. Processed: part-00088-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (242365, 47)
# Tamanho sampled_df: (12118, 47)
# 90. Processed: part-00089-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (240767, 47)
# Tamanho sampled_df: (12038, 47)
# 91. Processed: part-00090-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (260018, 47)
# Tamanho sampled_df: (13001, 47)
# 92. Processed: part-00091-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (211834, 47)
# Tamanho sampled_df: (10592, 47)
# 93. Processed: part-00092-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (253869, 47)
# Tamanho sampled_df: (12693, 47)
# 94. Processed: part-00093-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (428621, 47)
# Tamanho sampled_df: (21431, 47)
# 95. Processed: part-00094-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (444222, 47)
# Tamanho sampled_df: (22211, 47)
# 96. Processed: part-00095-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (255132, 47)
# Tamanho sampled_df: (12757, 47)
# 97. Processed: part-00096-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (244583, 47)
# Tamanho sampled_df: (12229, 47)
# 98. Processed: part-00097-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (446795, 47)
# Tamanho sampled_df: (22340, 47)
# 99. Processed: part-00098-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (241728, 47)
# Tamanho sampled_df: (12086, 47)
# 100. Processed: part-00099-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (225908, 47)
# Tamanho sampled_df: (11295, 47)
# 101. Processed: part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (233745, 47)
# Tamanho sampled_df: (11687, 47)
# 102. Processed: part-00101-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (231907, 47)
# Tamanho sampled_df: (11595, 47)
# 103. Processed: part-00102-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (252487, 47)
# Tamanho sampled_df: (12624, 47)
# 104. Processed: part-00103-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (223529, 47)
# Tamanho sampled_df: (11176, 47)
# 105. Processed: part-00104-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (231756, 47)
# Tamanho sampled_df: (11588, 47)
# 106. Processed: part-00105-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (250850, 47)
# Tamanho sampled_df: (12542, 47)
# 107. Processed: part-00106-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (223506, 47)
# Tamanho sampled_df: (11175, 47)
# 108. Processed: part-00107-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (231694, 47)
# Tamanho sampled_df: (11585, 47)
# 109. Processed: part-00108-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (262918, 47)
# Tamanho sampled_df: (13146, 47)
# 110. Processed: part-00109-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (236752, 47)
# Tamanho sampled_df: (11838, 47)
# 111. Processed: part-00110-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (269253, 47)
# Tamanho sampled_df: (13463, 47)
# 112. Processed: part-00111-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (253575, 47)
# Tamanho sampled_df: (12679, 47)
# 113. Processed: part-00112-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (451498, 47)
# Tamanho sampled_df: (22575, 47)
# 114. Processed: part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239887, 47)
# Tamanho sampled_df: (11994, 47)
# 115. Processed: part-00114-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (218872, 47)
# Tamanho sampled_df: (10944, 47)
# 116. Processed: part-00115-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (244797, 47)
# Tamanho sampled_df: (12240, 47)
# 117. Processed: part-00116-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (243486, 47)
# Tamanho sampled_df: (12174, 47)
# 118. Processed: part-00117-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (219849, 47)
# Tamanho sampled_df: (10992, 47)
# 119. Processed: part-00118-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239892, 47)
# Tamanho sampled_df: (11995, 47)
# 120. Processed: part-00119-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (235181, 47)
# Tamanho sampled_df: (11759, 47)
# 121. Processed: part-00120-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (246561, 47)
# Tamanho sampled_df: (12328, 47)
# 122. Processed: part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (248224, 47)
# Tamanho sampled_df: (12411, 47)
# 123. Processed: part-00122-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (256571, 47)
# Tamanho sampled_df: (12829, 47)
# 124. Processed: part-00123-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (248704, 47)
# Tamanho sampled_df: (12435, 47)
# 125. Processed: part-00124-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (448643, 47)
# Tamanho sampled_df: (22432, 47)
# 126. Processed: part-00125-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (234604, 47)
# Tamanho sampled_df: (11730, 47)
# 127. Processed: part-00126-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (447735, 47)
# Tamanho sampled_df: (22387, 47)
# 128. Processed: part-00127-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239666, 47)
# Tamanho sampled_df: (11983, 47)
# 129. Processed: part-00128-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (229641, 47)
# Tamanho sampled_df: (11482, 47)
# 130. Processed: part-00129-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (256955, 47)
# Tamanho sampled_df: (12848, 47)
# 131. Processed: part-00130-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (445755, 47)
# Tamanho sampled_df: (22288, 47)
# 132. Processed: part-00131-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239097, 47)
# Tamanho sampled_df: (11955, 47)
# 133. Processed: part-00132-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239831, 47)
# Tamanho sampled_df: (11992, 47)
# 134. Processed: part-00133-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (243649, 47)
# Tamanho sampled_df: (12182, 47)
# 135. Processed: part-00134-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239203, 47)
# Tamanho sampled_df: (11960, 47)
# 136. Processed: part-00135-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (444704, 47)
# Tamanho sampled_df: (22235, 47)
# 137. Processed: part-00136-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (256459, 47)
# Tamanho sampled_df: (12823, 47)
# 138. Processed: part-00137-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (446836, 47)
# Tamanho sampled_df: (22342, 47)
# 139. Processed: part-00138-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (242144, 47)
# Tamanho sampled_df: (12107, 47)
# 140. Processed: part-00139-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (449215, 47)
# Tamanho sampled_df: (22461, 47)
# 141. Processed: part-00140-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (223999, 47)
# Tamanho sampled_df: (11200, 47)
# 142. Processed: part-00141-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (260694, 47)
# Tamanho sampled_df: (13035, 47)
# 143. Processed: part-00142-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239202, 47)
# Tamanho sampled_df: (11960, 47)
# 144. Processed: part-00143-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (244859, 47)
# Tamanho sampled_df: (12243, 47)
# 145. Processed: part-00144-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (442721, 47)
# Tamanho sampled_df: (22136, 47)
# 146. Processed: part-00145-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (227148, 47)
# Tamanho sampled_df: (11357, 47)
# 147. Processed: part-00146-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (237858, 47)
# Tamanho sampled_df: (11893, 47)
# 148. Processed: part-00147-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (235009, 47)
# Tamanho sampled_df: (11750, 47)
# 149. Processed: part-00148-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (445891, 47)
# Tamanho sampled_df: (22295, 47)
# 150. Processed: part-00149-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (232166, 47)
# Tamanho sampled_df: (11608, 47)
# 151. Processed: part-00150-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (229627, 47)
# Tamanho sampled_df: (11481, 47)
# 152. Processed: part-00151-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (446751, 47)
# Tamanho sampled_df: (22338, 47)
# 153. Processed: part-00152-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (435001, 47)
# Tamanho sampled_df: (21750, 47)
# 154. Processed: part-00153-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (232216, 47)
# Tamanho sampled_df: (11611, 47)
# 155. Processed: part-00154-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (229855, 47)
# Tamanho sampled_df: (11493, 47)
# 156. Processed: part-00155-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (256428, 47)
# Tamanho sampled_df: (12821, 47)
# 157. Processed: part-00156-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (239934, 47)
# Tamanho sampled_df: (11997, 47)
# 158. Processed: part-00157-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (230476, 47)
# Tamanho sampled_df: (11524, 47)
# 159. Processed: part-00158-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (231318, 47)
# Tamanho sampled_df: (11566, 47)
# 160. Processed: part-00159-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (231306, 47)
# Tamanho sampled_df: (11565, 47)
# 161. Processed: part-00160-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (232463, 47)
# Tamanho sampled_df: (11623, 47)
# 162. Processed: part-00161-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (439594, 47)
# Tamanho sampled_df: (21980, 47)
# 163. Processed: part-00162-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (233587, 47)
# Tamanho sampled_df: (11679, 47)
# 164. Processed: part-00163-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (447638, 47)
# Tamanho sampled_df: (22382, 47)
# 165. Processed: part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (444417, 47)
# Tamanho sampled_df: (22221, 47)
# 166. Processed: part-00165-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (449009, 47)
# Tamanho sampled_df: (22450, 47)
# 167. Processed: part-00166-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (227688, 47)
# Tamanho sampled_df: (11384, 47)
# 168. Processed: part-00167-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Tamanho df: (234745, 47)
# Tamanho sampled_df: (11737, 47)
# 169. Processed: part-00168-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Dados importados com shape: (2334322, 47)
# Distribuição do label:
# label
# DDoS-ICMP_Flood            360668
# DDoS-UDP_Flood             270507
# DDoS-TCP_Flood             224345
# DDoS-PSHACK_Flood          203975
# DDoS-SYN_Flood             203438
# DDoS-RSTFINFlood           202181
# DDoS-SynonymousIP_Flood    180243
# DoS-UDP_Flood              165922
# DoS-TCP_Flood              133678
# DoS-SYN_Flood              101620
# BenignTraffic               54926
# Mirai-greeth_flood          49964
# Mirai-udpplain              44110
# Mirai-greip_flood           37642
# DDoS-ICMP_Fragmentation     22488
# MITM-ArpSpoofing            15530
# DDoS-UDP_Fragmentation      14454
# DDoS-ACK_Fragmentation      14183
# DNS_Spoofing                 8884
# Recon-HostDiscovery          6664
# Recon-OSScan                 4850
# Recon-PortScan               3999
# DoS-HTTP_Flood               3583
# VulnerabilityScan            1924
# DDoS-HTTP_Flood              1414
# DDoS-SlowLoris               1127
# DictionaryBruteForce          635
# CommandInjection              290
# BrowserHijacking              288
# SqlInjection                  245
# XSS                           193
# Backdoor_Malware              157
# Recon-PingSweep               134
# Uploading_Attack               61
# Name: count, dtype: int64
# Dados para AL com shape: (2334322, 48)
# Salvar dataset
# Salvar dataset... DONE

# %%
print(concatenated_df['label'].value_counts())
# Out:
# label
# DDoS-ICMP_Flood            360433
# DDoS-UDP_Flood             270879
# DDoS-TCP_Flood             225137
# DDoS-PSHACK_Flood          204628
# DDoS-SYN_Flood             202382
# DDoS-RSTFINFlood           201733
# DDoS-SynonymousIP_Flood    179455
# DoS-UDP_Flood              166179
# DoS-TCP_Flood              133526
# DoS-SYN_Flood              101903
# BenignTraffic               55626
# Mirai-greeth_flood          49261
# Mirai-udpplain              44467
# Mirai-greip_flood           37398
# DDoS-ICMP_Fragmentation     22912
# MITM-ArpSpoofing            15393
# DDoS-UDP_Fragmentation      14361
# DDoS-ACK_Fragmentation      14320
# DNS_Spoofing                 8670
# Recon-HostDiscovery          6554
# Recon-OSScan                 4938
# Recon-PortScan               4163
# DoS-HTTP_Flood               3630
# VulnerabilityScan            1822
# DDoS-HTTP_Flood              1423
# DDoS-SlowLoris               1195
# DictionaryBruteForce          623
# BrowserHijacking              277
# CommandInjection              266
# SqlInjection                  261
# XSS                           178
# Backdoor_Malware              150
# Recon-PingSweep               119
# Uploading_Attack               60
# Name: count, dtype: int64
