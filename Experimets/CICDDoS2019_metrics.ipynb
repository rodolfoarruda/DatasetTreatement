# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate

import time
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, balanced_accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# Algos
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

###########################

# %%
labels_file=pd.read_csv("/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/02-TreatedDataset/CICDDoS2019_labels.csv",header=None)

# %%
labels_file.value_counts()
# Out:
# TFTP             1004133
# DrDoS_SNMP        257990
# DrDoS_DNS         253566
# DrDoS_MSSQL       226144
# DrDoS_NetBIOS     204666
# DrDoS_UDP         156729
# DrDoS_SSDP        130531
# DrDoS_LDAP        108996
# Syn                79114
# DrDoS_NTP          60124
# UDP-lag            18341
# BENIGN              2796
# WebDDoS               25
# Name: count, dtype: int64

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-06-24/CICDDoS2019-LC-s100.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-06-24/CICDDoS2019-LC-s200.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-06-24/CICDDoS2019-LC-s300.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-06-24/CICDDoS2019-LC-s400.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-06-24/CICDDoS2019-LC-s500.npy', allow_pickle=True).item()

# %%
data = data1

# %%
data1[150026]
# Out:
# {'querying_time': [4.341985500010196],
#  'classification_time': [7.753912599990144],
#  'accuracy': [0.8192801888815057],
#  'balanced_accuracy': [0.6546047223239531],
#  'selected_indices': [[153829,
#    745771,
#    905807,
#    1590550,
#    1082947,
#    162695,
#    262638,
#    644619,
#    1441568,
#    456805,
#    706607,
#    331974,
#    395833,
#    237859,
#    1259816,
#    298952,
#    395526,
#    1554029,
#    247443,
#    680651,
#    1329203,
#    905376,
#    1478513,
#    726155,
#    854277,
#    1506869,
#    1441853,
#    1568276,
#    1184395,
#    849714,
#    361935,
#    680143,
#    742230,
#    1084179,
#    290893,
#    247631,
#    788214,
#    1275993,
#    498938,
#    1455447,
#    1524521,
#    1084433,
#    163515,
#    964983,
#    247804,
#    157436,
#    1394234,
#    878989,
#    1239537,
#    997618,
#    1239519,
#    927330,
#    262983,
#    1341056,
#    15081,
#    1325799,
#    790770,
#    1506721,
#    804765,
#    783705,
# ...

# %%
querying_time1 = []
classification_time1 = []
for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

print(len(classification_time1[0:301]))
print((classification_time1[0:301]))

# 7.753912599990144
# Out:
# 301
# ...

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:301]) + \
                               sum(querying_time2[0:301]) + \
                               sum(querying_time3[0:301]) + \
                               sum(querying_time4[0:301]) + \
                               sum(querying_time5[0:301]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:301])/60 , \
                                    sum(querying_time2[0:301])/60 , \
                                    sum(querying_time3[0:301])/60 , \
                                    sum(querying_time4[0:301])/60 , \
                                    sum(querying_time5[0:301])/60 ])))

print("query time iteration média:",(  data1[150026]['querying_time'][0] + \
                                    data2[150026]['querying_time'][0] + \
                                    data3[150026]['querying_time'][0] + \
                                    data4[150026]['querying_time'][0] + \
                                    data5[150026]['querying_time'][0] )/5)

print("query time iteration desvio:" , np.std(np.array([ data1[150026]['querying_time'][0] , \
                                    data2[150026]['querying_time'][0] , \
                                    data3[150026]['querying_time'][0] , \
                                    data4[150026]['querying_time'][0] , \
                                    data5[150026]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:301]) + \
                                    sum(classification_time2[0:301]) + \
                                    sum(classification_time3[0:301]) + \
                                    sum(classification_time4[0:301]) + \
                                    sum(classification_time5[0:301]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:301])/60 , \
                                    sum(classification_time2[0:301])/60 , \
                                    sum(classification_time3[0:301])/60 , \
                                    sum(classification_time4[0:301])/60 , \
                                    sum(classification_time5[0:301])/60 ])))

print("classification_time iteration média:",(  data1[150026]['classification_time'][0] + \
                                    data2[150026]['classification_time'][0] + \
                                    data3[150026]['classification_time'][0] + \
                                    data4[150026]['classification_time'][0] + \
                                    data5[150026]['classification_time'][0] )/5)

print("classification_time iteration desvio:" , np.std(np.array([ data1[150026]['classification_time'][0] , \
                                    data2[150026]['classification_time'][0] , \
                                    data3[150026]['classification_time'][0] , \
                                    data4[150026]['classification_time'][0] , \
                                    data5[150026]['classification_time'][0] ])))

print("Classes média:",(            data1[150026]['classes_know'][0] + \
                                    data2[150026]['classes_know'][0] + \
                                    data3[150026]['classes_know'][0] + \
                                    data4[150026]['classes_know'][0] + \
                                    data5[150026]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[150026]['classes_know'][0] , \
                                    data2[150026]['classes_know'][0] , \
                                    data3[150026]['classes_know'][0] , \
                                    data4[150026]['classes_know'][0] , \
                                    data5[150026]['classes_know'][0] ])))

print("Acurácia média:",(           data1[150026]['accuracy'][0] + \
                                    data2[150026]['accuracy'][0] + \
                                    data3[150026]['accuracy'][0] + \
                                    data4[150026]['accuracy'][0] + \
                                    data5[150026]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[150026]['accuracy'][0] , \
                                    data2[150026]['accuracy'][0] , \
                                    data3[150026]['accuracy'][0] , \
                                    data4[150026]['accuracy'][0] , \
                                    data5[150026]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[150026]['balanced_accuracy'][0] + \
                                    data2[150026]['balanced_accuracy'][0] + \
                                    data3[150026]['balanced_accuracy'][0] + \
                                    data4[150026]['balanced_accuracy'][0] + \
                                    data5[150026]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[150026]['balanced_accuracy'][0] , \
                                    data2[150026]['balanced_accuracy'][0] , \
                                    data3[150026]['balanced_accuracy'][0] , \
                                    data4[150026]['balanced_accuracy'][0] , \
                                    data5[150026]['balanced_accuracy'][0] ])))

# Definir as classes únicas esperadas
unique_classes = ['BENIGN','TFTP','DrDoS_SNMP','DrDoS_DNS','DrDoS_MSSQL', \
                  'DrDoS_NetBIOS','DrDoS_UDP','DrDoS_SSDP','DrDoS_LDAP','Syn','DrDoS_NTP','UDP-lag','WebDDoS']

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[150026]['classes'][0],
    data2[150026]['classes'][0],
    data3[150026]['classes'][0],
    data4[150026]['classes'][0],
    data5[150026]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 20.834260267335097
# querying_time desvio: 5.155861842139703
# query time iteration média: 4.039725440001348
# query time iteration desvio: 0.8908371435571419
# classification_time médio: 11.206881558331977
# classification_time desvio: 3.7092937902277203
# classification_time iteration média: 5.497130119997019
# classification_time iteration desvio: 0.6532064080330928
# Classes média: 12.6
# Classes desvio: 0.48989794855663565
# Acurácia média: 0.8484902396573926
# Acurácia desvio: 0.009038123262764874
# balanced accuracy média: 0.681305379129185
# balanced accuracy desvio: 0.007088226311718338
# +---------------+--------------+
# | Classe        |   Frequência |
# +===============+==============+
# | BENIGN        |            5 |
# +---------------+--------------+
# | TFTP          |            5 |
# +---------------+--------------+
# | DrDoS_SNMP    |            5 |
# +---------------+--------------+
# | DrDoS_DNS     |            5 |
# ...
