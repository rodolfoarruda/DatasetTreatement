# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate

import time
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, balanced_accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# Algos
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

###########################

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/NSL-KDD/03-Experiments/2024-06-17/nslkdd-EN-s100.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/NSL-KDD/03-Experiments/2024-06-17/nslkdd-EN-s200.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/NSL-KDD/03-Experiments/2024-06-17/nslkdd-EN-s300.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/NSL-KDD/03-Experiments/2024-06-17/nslkdd-EN-s400.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/NSL-KDD/03-Experiments/2024-06-17/nslkdd-EN-s500.npy', allow_pickle=True).item()

# %%
data1[15010]
# Out:
# {'querying_time': [0.09136879991274327],
#  'classification_time': [0.13349919999018312],
#  'accuracy': [0.9954888230541341],
#  'balanced_accuracy': [0.8487095807985525],
#  'selected_indices': [[35411,
#    52289,
#    29750,
#    21456,
#    86543,
#    79114,
#    56896,
#    31470,
#    80111,
#    45191,
#    18250,
#    46860,
#    73618,
#    32386,
#    86215,
#    49338,
#    24647,
#    19045,
#    76328,
#    26234,
#    21485,
#    1757,
#    69533,
#    1753,
#    49330,
#    13396,
#    37983,
#    63228,
#    57729,
#    11591,
#    81286,
#    23069,
#    60303,
#    10592,
#    47562,
#    84239,
#    37236,
#    5273,
#    75368,
#    57303,
#    48524,
#    12944,
#    22595,
#    18225,
#    20344,
#    80134,
#    40987,
#    14388,
#    22026,
#    46827,
#    80137,
#    27783,
#    65351,
#    48013,
#    43546,
#    67896,
#    3278,
#    59493,
#    89393,
#    20339,
#    64243,
#    32416,
#    5344,
#    17155,
#    5345,
#    71143,
#    21517,
# ...

# %%
querying_time1 = []
classification_time1 = []
for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

print(len(classification_time1[0:31]))
print((classification_time1[0:31]))
#[0.13349919999018312]
# Out:
# 31
# [0.008933500037528574, 0.011240200023166835, 0.013299299986101687, 0.0173258000286296, 0.02022059995215386, 0.023381799925118685, 0.03211469994857907, 0.03242400009185076, 0.04211639997083694, 0.04930279997643083, 0.04509100003633648, 0.049713300075381994, 0.06170279998332262, 0.06766270007938147, 0.07124800002202392, 0.0632521000225097, 0.08407869993243366, 0.0843814000254497, 0.07623140001669526, 0.09339249995537102, 0.10334249993320554, 0.10335079999640584, 0.10913090000394732, 0.11024999991059303, 0.11821620003320277, 0.11763889994472265, 0.12593640002887696, 0.12931009999010712, 0.13338909996673465, 0.13538540003355592, 0.14175740000791848]

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:31]) + \
                               sum(querying_time2[0:31]) + \
                               sum(querying_time3[0:31]) + \
                               sum(querying_time4[0:31]) + \
                               sum(querying_time5[0:31]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:31])/60 , \
                                    sum(querying_time2[0:31])/60 , \
                                    sum(querying_time3[0:31])/60 , \
                                    sum(querying_time4[0:31])/60 , \
                                    sum(querying_time5[0:31])/60 ])))

print("query time iteration média:",(  data1[15010]['querying_time'][0] + \
                                    data2[15010]['querying_time'][0] + \
                                    data3[15010]['querying_time'][0] + \
                                    data4[15010]['querying_time'][0] + \
                                    data5[15010]['querying_time'][0] )/5/60)

print("query time iteration desvio:" , np.std(np.array([ data1[15010]['querying_time'][0] , \
                                    data2[15010]['querying_time'][0] , \
                                    data3[15010]['querying_time'][0] , \
                                    data4[15010]['querying_time'][0] , \
                                    data5[15010]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:31]) + \
                                    sum(classification_time2[0:31]) + \
                                    sum(classification_time3[0:31]) + \
                                    sum(classification_time4[0:31]) + \
                                    sum(classification_time5[0:31]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:31])/60 , \
                                    sum(classification_time2[0:31])/60 , \
                                    sum(classification_time3[0:31])/60 , \
                                    sum(classification_time4[0:31])/60 , \
                                    sum(classification_time5[0:31])/60 ])))

print("classification_time iteration média:",(  data1[15010]['classification_time'][0] + \
                                    data2[15010]['classification_time'][0] + \
                                    data3[15010]['classification_time'][0] + \
                                    data4[15010]['classification_time'][0] + \
                                    data5[15010]['classification_time'][0] )/5/60)

print("classification_time iteration desvio:" , np.std(np.array([ data1[15010]['classification_time'][0] , \
                                    data2[15010]['classification_time'][0] , \
                                    data3[15010]['classification_time'][0] , \
                                    data4[15010]['classification_time'][0] , \
                                    data5[15010]['classification_time'][0] ])))

print("Classes média:",(            data1[15010]['classes_know'][0] + \
                                    data2[15010]['classes_know'][0] + \
                                    data3[15010]['classes_know'][0] + \
                                    data4[15010]['classes_know'][0] + \
                                    data5[15010]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[15010]['classes_know'][0] , \
                                    data2[15010]['classes_know'][0] , \
                                    data3[15010]['classes_know'][0] , \
                                    data4[15010]['classes_know'][0] , \
                                    data5[15010]['classes_know'][0] ])))

print("Acurácia média:",(           data1[15010]['accuracy'][0] + \
                                    data2[15010]['accuracy'][0] + \
                                    data3[15010]['accuracy'][0] + \
                                    data4[15010]['accuracy'][0] + \
                                    data5[15010]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[15010]['accuracy'][0] , \
                                    data2[15010]['accuracy'][0] , \
                                    data3[15010]['accuracy'][0] , \
                                    data4[15010]['accuracy'][0] , \
                                    data5[15010]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[15010]['balanced_accuracy'][0] + \
                                    data2[15010]['balanced_accuracy'][0] + \
                                    data3[15010]['balanced_accuracy'][0] + \
                                    data4[15010]['balanced_accuracy'][0] + \
                                    data5[15010]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[15010]['balanced_accuracy'][0] , \
                                    data2[15010]['balanced_accuracy'][0] , \
                                    data3[15010]['balanced_accuracy'][0] , \
                                    data4[15010]['balanced_accuracy'][0] , \
                                    data5[15010]['balanced_accuracy'][0] ])))


# Definir as classes únicas esperadas
unique_classes = ['Access', 'DoS', 'Normal', 'Privilege', 'Probe']

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[15010]['classes'][0],
    data2[15010]['classes'][0],
    data3[15010]['classes'][0],
    data4[15010]['classes'][0],
    data5[15010]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 0.059580394998968896
# querying_time desvio: 0.007589294838230428
# query time iteration média: 0.0017363436663678537
# query time iteration desvio: 0.015160143179775444
# classification_time médio: 0.0422549429978244
# classification_time desvio: 0.005172467963617778
# classification_time iteration média: 0.0025878410002527137
# classification_time iteration desvio: 0.016763701411057968
# Classes média: 4.8
# Classes desvio: 0.39999999999999997
# Acurácia média: 0.9950085285932311
# Acurácia desvio: 0.0003069453451347319
# balanced accuracy média: 0.8727359932663855
# balanced accuracy desvio: 0.013045748581216482
# +-----------+--------------+
# | Classe    |   Frequência |
# +===========+==============+
# | Access    |            5 |
# +-----------+--------------+
# | DoS       |            5 |
# +-----------+--------------+
# | Normal    |            5 |
# +-----------+--------------+
# | Privilege |            4 |
# +-----------+--------------+
# ...
