# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate
import time
###########################

# %%
labels_file=pd.read_csv("/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/02-TreatedDataset/NB15_labels.csv",header=None)

# %%
labels_file.value_counts()
# Out:
# Normal            2218764
# Generic            215481
# Exploits            44525
# Fuzzers             24246
# DoS                 16353
# Reconnaissance      13987
# Analysis             2677
# Backdoor             2329
# Shellcode            1511
# Worms                 174
# Name: count, dtype: int64

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-06-12/NB15-MS-s1-15p.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-06-12/NB15-MS-s20-15p.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-06-12/NB15-MS-s300-15p.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-06-12/NB15-MS-s400-15p.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-06-12/NB15-MS-s500-15p.npy', allow_pickle=True).item()

# %%
data1[70020]
# Out:
# {'querying_time': [2.2092146999784745],
#  'classification_time': [1.7011432999861427],
#  'accuracy': [0.9797471178388877],
#  'balanced_accuracy': [0.527105772861218],
#  'selected_indices': [[151570,
#    857474,
#    500042,
#    1376219,
#    360194,
#    1207114,
#    1608786,
#    555476,
#    273524,
#    10691,
#    59405,
#    1145906,
#    413951,
#    185705,
#    543719,
#    404688,
#    1411,
#    1359972,
#    1339208,
#    418973,
#    962845,
#    1344571,
#    377283,
#    156509,
#    195979,
#    1259746,
#    1333880,
#    198895,
#    206708,
#    923264,
#    1383551,
#    1215687,
#    89088,
#    573406,
#    816702,
#    6360,
#    929880,
#    1655178,
#    1013644,
#    28764,
#    1330635,
#    938696,
#    382385,
#    677391,
#    1273274,
#    40136,
#    1672921,
#    71568,
#    1117037,
#    282809,
#    1628694,
#    1270381,
#    181089,
#    725948,
#    634794,
#    151179,
#    537814,
#    40426,
#    867799,
#    977288,
#    431452,
# ...

# %%
querying_time1 = []
classification_time1 = []
for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

print(len(classification_time1[0:141]))
print((classification_time1[0:141]))
#[1.7011432999861427]
# Out:
# 141
# ...

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:141]) + \
                               sum(querying_time2[0:141]) + \
                               sum(querying_time3[0:141]) + \
                               sum(querying_time4[0:141]) + \
                               sum(querying_time5[0:141]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:141])/60 , \
                                    sum(querying_time2[0:141])/60 , \
                                    sum(querying_time3[0:141])/60 , \
                                    sum(querying_time4[0:141])/60 , \
                                    sum(querying_time5[0:141])/60 ])))

print("query time iteration média:",(  data1[70020]['querying_time'][0] + \
                                    data2[70020]['querying_time'][0] + \
                                    data3[70020]['querying_time'][0] + \
                                    data4[70020]['querying_time'][0] + \
                                    data5[70020]['querying_time'][0] )/5)

print("query time iteration desvio:" , np.std(np.array([ data1[70020]['querying_time'][0] , \
                                    data2[70020]['querying_time'][0] , \
                                    data3[70020]['querying_time'][0] , \
                                    data4[70020]['querying_time'][0] , \
                                    data5[70020]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:141]) + \
                                    sum(classification_time2[0:141]) + \
                                    sum(classification_time3[0:141]) + \
                                    sum(classification_time4[0:141]) + \
                                    sum(classification_time5[0:141]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:141])/60 , \
                                    sum(classification_time2[0:141])/60 , \
                                    sum(classification_time3[0:141])/60 , \
                                    sum(classification_time4[0:141])/60 , \
                                    sum(classification_time5[0:141])/60 ])))

print("classification_time iteration média:",(  data1[70020]['classification_time'][0] + \
                                    data2[70020]['classification_time'][0] + \
                                    data3[70020]['classification_time'][0] + \
                                    data4[70020]['classification_time'][0] + \
                                    data5[70020]['classification_time'][0] )/5)

print("classification_time iteration desvio:" , np.std(np.array([ data1[70020]['classification_time'][0] , \
                                    data2[70020]['classification_time'][0] , \
                                    data3[70020]['classification_time'][0] , \
                                    data4[70020]['classification_time'][0] , \
                                    data5[70020]['classification_time'][0] ])))

print("Classes média:",(            data1[70020]['classes_know'][0] + \
                                    data2[70020]['classes_know'][0] + \
                                    data3[70020]['classes_know'][0] + \
                                    data4[70020]['classes_know'][0] + \
                                    data5[70020]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[70020]['classes_know'][0] , \
                                    data2[70020]['classes_know'][0] , \
                                    data3[70020]['classes_know'][0] , \
                                    data4[70020]['classes_know'][0] , \
                                    data5[70020]['classes_know'][0] ])))

print("Acurácia média:",(           data1[70020]['accuracy'][0] + \
                                    data2[70020]['accuracy'][0] + \
                                    data3[70020]['accuracy'][0] + \
                                    data4[70020]['accuracy'][0] + \
                                    data5[70020]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[70020]['accuracy'][0] , \
                                    data2[70020]['accuracy'][0] , \
                                    data3[70020]['accuracy'][0] , \
                                    data4[70020]['accuracy'][0] , \
                                    data5[70020]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[70020]['balanced_accuracy'][0] + \
                                    data2[70020]['balanced_accuracy'][0] + \
                                    data3[70020]['balanced_accuracy'][0] + \
                                    data4[70020]['balanced_accuracy'][0] + \
                                    data5[70020]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[70020]['balanced_accuracy'][0] , \
                                    data2[70020]['balanced_accuracy'][0] , \
                                    data3[70020]['balanced_accuracy'][0] , \
                                    data4[70020]['balanced_accuracy'][0] , \
                                    data5[70020]['balanced_accuracy'][0] ])))


# Definir as classes únicas esperadas
unique_classes = ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS','Reconnaissance','Analysis','Backdoor','Shellcode','Worms']

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[70020]['classes'][0],
    data2[70020]['classes'][0],
    data3[70020]['classes'][0],
    data4[70020]['classes'][0],
    data5[70020]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 8.100514285669778
# querying_time desvio: 3.790402191624236
# query time iteration média: 3.088178500009235
# query time iteration desvio: 1.556014723795655
# classification_time médio: 5.117082960335538
# classification_time desvio: 2.867483306388646
# classification_time iteration média: 3.598981019970961
# classification_time iteration desvio: 2.2352683520640384
# Classes média: 10.0
# Classes desvio: 0.0
# Acurácia média: 0.9803145607369933
# Acurácia desvio: 0.00013142404259755956
# balanced accuracy média: 0.5279723767726592
# balanced accuracy desvio: 0.003696661655435646
# +----------------+--------------+
# | Classe         |   Frequência |
# +================+==============+
# | Normal         |            5 |
# +----------------+--------------+
# | Generic        |            5 |
# +----------------+--------------+
# | Exploits       |            5 |
# +----------------+--------------+
# | Fuzzers        |            5 |
# ...
