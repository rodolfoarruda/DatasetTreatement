# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate
import time
###########################

# %%
labels_file=pd.read_csv("/content/drive/MyDrive/IntrusionDetection/WSN-DS/02-TreatedDataset/wsnds_labels.csv",header=None)

# %%
labels_file.value_counts()
# Out:
# Normal       340066
# Grayhole      14596
# Blackhole     10049
# TDMA           6638
# Flooding       3312
# Name: count, dtype: int64

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/WSN-DS/03-Experiments/2024-06-18/wsnds-EN-s100.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/WSN-DS/03-Experiments/2024-06-18/wsnds-EN-s200.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/WSN-DS/03-Experiments/2024-06-18/wsnds-EN-s300.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/WSN-DS/03-Experiments/2024-06-18/wsnds-EN-s400.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/WSN-DS/03-Experiments/2024-06-18/wsnds-EN-s500.npy', allow_pickle=True).item()

# %%
data1[7010]
# Out:
# {'querying_time': [0.11718369997106493],
#  'classification_time': [0.060331900021992624],
#  'accuracy': [0.9954625930835683],
#  'balanced_accuracy': [0.9722449913361899],
#  'selected_indices': [[58519,
#    24767,
#    202050,
#    187856,
#    10889,
#    147901,
#    57901,
#    136009,
#    20870,
#    237835,
#    235199,
#    185918,
#    5740,
#    113484,
#    169568,
#    230735,
#    243442,
#    191563,
#    75333,
#    34888,
#    139934,
#    234255,
#    123696,
#    160314,
#    216556,
#    212707,
#    21510,
#    64354,
#    141739,
#    17138,
#    57229,
#    236129,
#    43213,
#    121768,
#    19725,
#    12699,
#    6132,
#    62236,
#    11500,
#    15685,
#    26589,
#    30755,
#    62541,
#    124988,
#    61553,
#    53091,
#    162530,
#    58436,
#    73390,
#    252402,
#    84309,
#    30531,
#    223962,
#    90647,
#    157207,
#    92517,
#    60859,
#    91989,
#    147557,
#    193514,
#    119905,
#    42307,
#    221690,
#    240036,
# ...

# %%
querying_time1 = []
classification_time1 = []
for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

print(len(classification_time1[0:15]))
print((classification_time1[0:15]))
#[0.060331900021992624]
# Out:
# 15
# [0.007278400007635355, 0.010984900058247149, 0.013099599978886545, 0.017986199934966862, 0.019247199990786612, 0.024240999948233366, 0.0320324000203982, 0.03575390006881207, 0.04273580003064126, 0.039218800025992095, 0.04623990005347878, 0.05312179995235056, 0.04939200007356703, 0.0640642000362277, 0.060331900021992624]

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:15]) + \
                               sum(querying_time2[0:15]) + \
                               sum(querying_time3[0:15]) + \
                               sum(querying_time4[0:15]) + \
                               sum(querying_time5[0:15]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:15])/60 , \
                                    sum(querying_time2[0:15])/60 , \
                                    sum(querying_time3[0:15])/60 , \
                                    sum(querying_time4[0:15])/60 , \
                                    sum(querying_time5[0:15])/60 ])))

print("query time iteration média:",(  data1[7010]['querying_time'][0] + \
                                    data2[7010]['querying_time'][0] + \
                                    data3[7010]['querying_time'][0] + \
                                    data4[7010]['querying_time'][0] + \
                                    data5[7010]['querying_time'][0] )/5)

print("query time iteration desvio:" , np.std(np.array([ data1[7010]['querying_time'][0] , \
                                    data2[7010]['querying_time'][0] , \
                                    data3[7010]['querying_time'][0] , \
                                    data4[7010]['querying_time'][0] , \
                                    data5[7010]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:15]) + \
                                    sum(classification_time2[0:15]) + \
                                    sum(classification_time3[0:15]) + \
                                    sum(classification_time4[0:15]) + \
                                    sum(classification_time5[0:15]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:15])/60 , \
                                    sum(classification_time2[0:15])/60 , \
                                    sum(classification_time3[0:15])/60 , \
                                    sum(classification_time4[0:15])/60 , \
                                    sum(classification_time5[0:15])/60 ])))

print("classification_time iteration média:",(  data1[7010]['classification_time'][0] + \
                                    data2[7010]['classification_time'][0] + \
                                    data3[7010]['classification_time'][0] + \
                                    data4[7010]['classification_time'][0] + \
                                    data5[7010]['classification_time'][0] )/5)

print("classification_time iteration desvio:" , np.std(np.array([ data1[7010]['classification_time'][0] , \
                                    data2[7010]['classification_time'][0] , \
                                    data3[7010]['classification_time'][0] , \
                                    data4[7010]['classification_time'][0] , \
                                    data5[7010]['classification_time'][0] ])))

print("Classes média:",(            data1[7010]['classes_know'][0] + \
                                    data2[7010]['classes_know'][0] + \
                                    data3[7010]['classes_know'][0] + \
                                    data4[7010]['classes_know'][0] + \
                                    data5[7010]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[7010]['classes_know'][0] , \
                                    data2[7010]['classes_know'][0] , \
                                    data3[7010]['classes_know'][0] , \
                                    data4[7010]['classes_know'][0] , \
                                    data5[7010]['classes_know'][0] ])))

print("Acurácia média:",(           data1[7010]['accuracy'][0] + \
                                    data2[7010]['accuracy'][0] + \
                                    data3[7010]['accuracy'][0] + \
                                    data4[7010]['accuracy'][0] + \
                                    data5[7010]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[7010]['accuracy'][0] , \
                                    data2[7010]['accuracy'][0] , \
                                    data3[7010]['accuracy'][0] , \
                                    data4[7010]['accuracy'][0] , \
                                    data5[7010]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[7010]['balanced_accuracy'][0] + \
                                    data2[7010]['balanced_accuracy'][0] + \
                                    data3[7010]['balanced_accuracy'][0] + \
                                    data4[7010]['balanced_accuracy'][0] + \
                                    data5[7010]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[7010]['balanced_accuracy'][0] , \
                                    data2[7010]['balanced_accuracy'][0] , \
                                    data3[7010]['balanced_accuracy'][0] , \
                                    data4[7010]['balanced_accuracy'][0] , \
                                    data5[7010]['balanced_accuracy'][0] ])))

# Definir as classes únicas esperadas
unique_classes = ['Normal','Grayhole','Blackhole','TDMA','Flooding']

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[7010]['classes'][0],
    data2[7010]['classes'][0],
    data3[7010]['classes'][0],
    data4[7010]['classes'][0],
    data5[7010]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 0.10721887099789455
# querying_time desvio: 0.054006596684711916
# query time iteration média: 0.3194348199525848
# query time iteration desvio: 0.1680902922615899
# classification_time médio: 0.020246727331153427
# classification_time desvio: 0.011590901275319235
# classification_time iteration média: 0.15734439997468144
# classification_time iteration desvio: 0.09990954871462221
# Classes média: 5.0
# Classes desvio: 0.0
# Acurácia média: 0.995243729926423
# Acurácia desvio: 0.0003912441186779141
# balanced accuracy média: 0.9712375849576202
# balanced accuracy desvio: 0.0029522922283769007
# +-----------+--------------+
# | Classe    |   Frequência |
# +===========+==============+
# | Normal    |            5 |
# +-----------+--------------+
# | Grayhole  |            5 |
# +-----------+--------------+
# | Blackhole |            5 |
# +-----------+--------------+
# | TDMA      |            5 |
# +-----------+--------------+
# | Flooding  |            5 |
# ...
