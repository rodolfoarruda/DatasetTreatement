# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate
import time

###########################

# %%
labels_file=pd.read_csv("/content/drive/MyDrive/IntrusionDetection/CIC_IOT_2023/02-TreatedDataset/CICIoT2023-34_labels.csv",header=None)

# %%
labels_file.value_counts()
# Out:
# DDoS-ICMP_Flood            360668
# DDoS-UDP_Flood             270507
# DDoS-TCP_Flood             224345
# DDoS-PSHACK_Flood          203975
# DDoS-SYN_Flood             203438
# DDoS-RSTFINFlood           202181
# DDoS-SynonymousIP_Flood    180243
# DoS-UDP_Flood              165922
# DoS-TCP_Flood              133678
# DoS-SYN_Flood              101620
# BenignTraffic               54926
# Mirai-greeth_flood          49964
# Mirai-udpplain              44110
# Mirai-greip_flood           37642
# DDoS-ICMP_Fragmentation     22488
# MITM-ArpSpoofing            15530
# DDoS-UDP_Fragmentation      14454
# DDoS-ACK_Fragmentation      14183
# DNS_Spoofing                 8884
# Recon-HostDiscovery          6664
# Recon-OSScan                 4850
# Recon-PortScan               3999
# DoS-HTTP_Flood               3583
# VulnerabilityScan            1924
# DDoS-HTTP_Flood              1414
# DDoS-SlowLoris               1127
# DictionaryBruteForce          635
# ...

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/CIC_IOT_2023/03-Experiments/2024-07-05/CICIoT2023-LC-s100-a161.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/CIC_IOT_2023/03-Experiments/2024-07-05/CICIoT2023-LC-s200-a161.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/CIC_IOT_2023/03-Experiments/2024-07-05/CICIoT2023-LC-s300-a161.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/CIC_IOT_2023/03-Experiments/2024-07-05/CICIoT2023-LC-s400-a161.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/CIC_IOT_2023/03-Experiments/2024-07-05/CICIoT2023-LC-s500-a161.npy', allow_pickle=True).item()

# %%
data1[16568]
# Out:
# {'querying_time': [6.597711799899116],
#  'classification_time': [1.610996900126338],
#  'accuracy': [0.8893740798546902],
#  'balanced_accuracy': [0.6963970137267099],
#  'selected_indices': [[489151,
#    1135468,
#    1509365,
#    853500,
#    669691,
#    1322599,
#    153913,
#    497910,
#    643658,
#    430181,
#    486554,
#    1525764,
#    41196,
#    1031865,
#    1260844,
#    1273465,
#    573615,
#    1494246,
#    1180369,
#    541584,
#    754434,
#    399026,
#    326390,
#    429609,
#    1299093,
#    9537,
#    191923,
#    565750,
#    1339344,
#    260706,
#    108624,
#    1481050,
#    897466,
#    223229,
#    756277,
#    1614307,
#    1489856,
#    882338,
#    29549,
#    1247298,
#    217448,
#    752975,
#    573001,
#    21271,
#    235193,
#    398587,
#    1277945,
#    774355,
#    522426,
#    898205,
#    399760,
#    503996,
#    895300,
#    574395,
#    434912,
#    1463596,
#    1469160,
#    645494,
#    635687,
#    1002227,
#    751368,
# ...

# %%
querying_time1 = []
classification_time1 = []
for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

print(len(classification_time1[0:34]))
print((classification_time1[0:34]))

# 6.612062200001674
# Out:
# 161
# ...

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:34]) + \
                               sum(querying_time2[0:34]) + \
                               sum(querying_time3[0:34]) + \
                               sum(querying_time4[0:34]) + \
                               sum(querying_time5[0:34]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:34])/60 , \
                                    sum(querying_time2[0:34])/60 , \
                                    sum(querying_time3[0:34])/60 , \
                                    sum(querying_time4[0:34])/60 , \
                                    sum(querying_time5[0:34])/60 ])))

print("query time iteration média:",(  data1[16568]['querying_time'][0] + \
                                    data2[16568]['querying_time'][0] + \
                                    data3[16568]['querying_time'][0] + \
                                    data4[16568]['querying_time'][0] + \
                                    data5[16568]['querying_time'][0] )/5)

print("query time iteration desvio:" , np.std(np.array([ data1[16568]['querying_time'][0] , \
                                    data2[16568]['querying_time'][0] , \
                                    data3[16568]['querying_time'][0] , \
                                    data4[16568]['querying_time'][0] , \
                                    data5[16568]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:34]) + \
                                    sum(classification_time2[0:34]) + \
                                    sum(classification_time3[0:34]) + \
                                    sum(classification_time4[0:34]) + \
                                    sum(classification_time5[0:34]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:34])/60 , \
                                    sum(classification_time2[0:34])/60 , \
                                    sum(classification_time3[0:34])/60 , \
                                    sum(classification_time4[0:34])/60 , \
                                    sum(classification_time5[0:34])/60 ])))

print("classification_time iteration média:",(  data1[16568]['classification_time'][0] + \
                                    data2[16568]['classification_time'][0] + \
                                    data3[16568]['classification_time'][0] + \
                                    data4[16568]['classification_time'][0] + \
                                    data5[16568]['classification_time'][0] )/5)

print("classification_time iteration desvio:" , np.std(np.array([ data1[16568]['classification_time'][0] , \
                                    data2[16568]['classification_time'][0] , \
                                    data3[16568]['classification_time'][0] , \
                                    data4[16568]['classification_time'][0] , \
                                    data5[16568]['classification_time'][0] ])))

print("Classes média:",(            data1[16568]['classes_know'][0] + \
                                    data2[16568]['classes_know'][0] + \
                                    data3[16568]['classes_know'][0] + \
                                    data4[16568]['classes_know'][0] + \
                                    data5[16568]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[16568]['classes_know'][0] , \
                                    data2[16568]['classes_know'][0] , \
                                    data3[16568]['classes_know'][0] , \
                                    data4[16568]['classes_know'][0] , \
                                    data5[16568]['classes_know'][0] ])))

print("Acurácia média:",(           data1[16568]['accuracy'][0] + \
                                    data2[16568]['accuracy'][0] + \
                                    data3[16568]['accuracy'][0] + \
                                    data4[16568]['accuracy'][0] + \
                                    data5[16568]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[16568]['accuracy'][0] , \
                                    data2[16568]['accuracy'][0] , \
                                    data3[16568]['accuracy'][0] , \
                                    data4[16568]['accuracy'][0] , \
                                    data5[16568]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[16568]['balanced_accuracy'][0] + \
                                    data2[16568]['balanced_accuracy'][0] + \
                                    data3[16568]['balanced_accuracy'][0] + \
                                    data4[16568]['balanced_accuracy'][0] + \
                                    data5[16568]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[16568]['balanced_accuracy'][0] , \
                                    data2[16568]['balanced_accuracy'][0] , \
                                    data3[16568]['balanced_accuracy'][0] , \
                                    data4[16568]['balanced_accuracy'][0] , \
                                    data5[16568]['balanced_accuracy'][0] ])))

# Definir as classes únicas esperadas
unique_classes = ['DDoS-ICMP_Flood','DDoS-UDP_Flood','DDoS-TCP_Flood','DDoS-PSHACK_Flood','DDoS-SYN_Flood','DDoS-RSTFINFlood', \
                  'DDoS-SynonymousIP_Flood','DoS-UDP_Flood','DoS-TCP_Flood','DoS-SYN_Flood','BenignTraffic','Mirai-greeth_flood', \
                  'Mirai-udpplain','Mirai-greip_flood','DDoS-ICMP_Fragmentation','MITM-ArpSpoofing','DDoS-UDP_Fragmentation', \
                  'DDoS-ACK_Fragmentation','DNS_Spoofing','Recon-HostDiscovery','Recon-OSScan','Recon-PortScan','DoS-HTTP_Flood', \
                  'VulnerabilityScan','DDoS-HTTP_Flood','DDoS-SlowLoris','DictionaryBruteForce','CommandInjection','BrowserHijacking', \
                  'SqlInjection','XSS','Backdoor_Malware','Recon-PingSweep','Uploading_Attack'
                  ]

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[16568]['classes'][0],
    data2[16568]['classes'][0],
    data3[16568]['classes'][0],
    data4[16568]['classes'][0],
    data5[16568]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 2.584100707662292
# querying_time desvio: 0.405832861940055
# query time iteration média: 3.9738646999467164
# query time iteration desvio: 0.42850535647039484
# classification_time médio: 0.2925450919941068
# classification_time desvio: 0.05571692434551669
# classification_time iteration média: 1.1128004999831318
# classification_time iteration desvio: 0.19056373324374762
# Classes média: 31.2
# Classes desvio: 0.7483314773547882
# Acurácia média: 0.9585647232531341
# Acurácia desvio: 0.024307635443493916
# balanced accuracy média: 0.7220684763910552
# balanced accuracy desvio: 0.013281062716507828
# +-------------------------+--------------+
# | Classe                  |   Frequência |
# +=========================+==============+
# | DDoS-ICMP_Flood         |            5 |
# +-------------------------+--------------+
# | DDoS-UDP_Flood          |            5 |
# +-------------------------+--------------+
# | DDoS-TCP_Flood          |            5 |
# ...
