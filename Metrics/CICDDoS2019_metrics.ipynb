# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate
import time

###########################

# %%
labels_file=pd.read_csv("/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/02-TreatedDataset/CICDDoS2019_labels.csv",header=None)

# %%
labels_file.shape
# Out:
# (2503155, 1)

# %%
labels_file.value_counts()
# Out:
# TFTP             1004133
# DrDoS_SNMP        257990
# DrDoS_DNS         253566
# DrDoS_MSSQL       226144
# DrDoS_NetBIOS     204666
# DrDoS_UDP         156729
# DrDoS_SSDP        130531
# DrDoS_LDAP        108996
# Syn                79114
# DrDoS_NTP          60124
# UDP-lag            18341
# BENIGN              2796
# WebDDoS               25
# Name: count, dtype: int64

# %%
round((25/2503155)*100,6)
# Out:
# 0.000999

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-07-05/CICDDoS2019-LC-s100-a301.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-07-05/CICDDoS2019-LC-s200-a301.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-07-05/CICDDoS2019-LC-s300-a301.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-07-05/CICDDoS2019-LC-s400-a301.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/CICDDoS2019/03-Experiments/2024-07-05/CICDDoS2019-LC-s500-a301.npy', allow_pickle=True).item()

# %%
data = data1

# %%
data1[94026]
# Out:
# {'querying_time': [5.708571699913591],
#  'classification_time': [2.164652199950069],
#  'accuracy': [0.852136036231585],
#  'balanced_accuracy': [0.6772297340834209],
#  'selected_indices': [[607461,
#    770031,
#    1564884,
#    892785,
#    1038163,
#    1301911,
#    484479,
#    431132,
#    730556,
#    1356416,
#    929296,
#    1058953,
#    118294,
#    1626592,
#    1499475,
#    702181,
#    1600215,
#    694058,
#    977056,
#    1645503,
#    853828,
#    729932,
#    963135,
#    1019457,
#    572394,
#    576981,
#    436216,
#    493498,
#    1627040,
#    1222298,
#    313170,
#    783639,
#    641747,
#    976247,
#    857352,
#    715613,
#    685651,
#    1416774,
#    1627603,
#    1101300,
#    701619,
#    1369783,
#    565767,
#    947763,
#    1222903,
#    119381,
#    1060303,
#    284373,
#    513961,
#    139348,
#    1448521,
#    168134,
#    508485,
#    1190420,
#    1303824,
#    385693,
#    201092,
#    280483,
#    374506,
#    1416235,
# ...

# %%
querying_time1 = []
classification_time1 = []
for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

print(len(classification_time1[0:189]))
print((classification_time1[0:189]))

# 7.753912599990144
# Out:
# 189
# ...

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:189]) + \
                               sum(querying_time2[0:189]) + \
                               sum(querying_time3[0:189]) + \
                               sum(querying_time4[0:189]) + \
                               sum(querying_time5[0:189]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:189])/60 , \
                                    sum(querying_time2[0:189])/60 , \
                                    sum(querying_time3[0:189])/60 , \
                                    sum(querying_time4[0:189])/60 , \
                                    sum(querying_time5[0:189])/60 ])))

print("query time iteration média:",(  data1[94026]['querying_time'][0] + \
                                    data2[94026]['querying_time'][0] + \
                                    data3[94026]['querying_time'][0] + \
                                    data4[94026]['querying_time'][0] + \
                                    data5[94026]['querying_time'][0] )/5)

print("query time iteration desvio:" , np.std(np.array([ data1[94026]['querying_time'][0] , \
                                    data2[94026]['querying_time'][0] , \
                                    data3[94026]['querying_time'][0] , \
                                    data4[94026]['querying_time'][0] , \
                                    data5[94026]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:189]) + \
                                    sum(classification_time2[0:189]) + \
                                    sum(classification_time3[0:189]) + \
                                    sum(classification_time4[0:189]) + \
                                    sum(classification_time5[0:189]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:189])/60 , \
                                    sum(classification_time2[0:189])/60 , \
                                    sum(classification_time3[0:189])/60 , \
                                    sum(classification_time4[0:189])/60 , \
                                    sum(classification_time5[0:189])/60 ])))

print("classification_time iteration média:",(  data1[94026]['classification_time'][0] + \
                                    data2[94026]['classification_time'][0] + \
                                    data3[94026]['classification_time'][0] + \
                                    data4[94026]['classification_time'][0] + \
                                    data5[94026]['classification_time'][0] )/5)

print("classification_time iteration desvio:" , np.std(np.array([ data1[94026]['classification_time'][0] , \
                                    data2[94026]['classification_time'][0] , \
                                    data3[94026]['classification_time'][0] , \
                                    data4[94026]['classification_time'][0] , \
                                    data5[94026]['classification_time'][0] ])))

print("Classes média:",(            data1[94026]['classes_know'][0] + \
                                    data2[94026]['classes_know'][0] + \
                                    data3[94026]['classes_know'][0] + \
                                    data4[94026]['classes_know'][0] + \
                                    data5[94026]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[94026]['classes_know'][0] , \
                                    data2[94026]['classes_know'][0] , \
                                    data3[94026]['classes_know'][0] , \
                                    data4[94026]['classes_know'][0] , \
                                    data5[94026]['classes_know'][0] ])))

print("Acurácia média:",(           data1[94026]['accuracy'][0] + \
                                    data2[94026]['accuracy'][0] + \
                                    data3[94026]['accuracy'][0] + \
                                    data4[94026]['accuracy'][0] + \
                                    data5[94026]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[94026]['accuracy'][0] , \
                                    data2[94026]['accuracy'][0] , \
                                    data3[94026]['accuracy'][0] , \
                                    data4[94026]['accuracy'][0] , \
                                    data5[94026]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[94026]['balanced_accuracy'][0] + \
                                    data2[94026]['balanced_accuracy'][0] + \
                                    data3[94026]['balanced_accuracy'][0] + \
                                    data4[94026]['balanced_accuracy'][0] + \
                                    data5[94026]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[94026]['balanced_accuracy'][0] , \
                                    data2[94026]['balanced_accuracy'][0] , \
                                    data3[94026]['balanced_accuracy'][0] , \
                                    data4[94026]['balanced_accuracy'][0] , \
                                    data5[94026]['balanced_accuracy'][0] ])))

# Definir as classes únicas esperadas
unique_classes = ['BENIGN','TFTP','DrDoS_SNMP','DrDoS_DNS','DrDoS_MSSQL', \
                  'DrDoS_NetBIOS','DrDoS_UDP','DrDoS_SSDP','DrDoS_LDAP','Syn','DrDoS_NTP','UDP-lag','WebDDoS']

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[94026]['classes'][0],
    data2[94026]['classes'][0],
    data3[94026]['classes'][0],
    data4[94026]['classes'][0],
    data5[94026]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 43.214689371675874
# querying_time desvio: 31.55099953185007
# query time iteration média: 4.422621659934521
# query time iteration desvio: 0.497116549469957
# classification_time médio: 3.104356072673108
# classification_time desvio: 0.5411112693886564
# classification_time iteration média: 2.164100859966129
# classification_time iteration desvio: 0.1682086039840109
# Classes média: 12.6
# Classes desvio: 0.48989794855663565
# Acurácia média: 0.8428192668723625
# Acurácia desvio: 0.008272635524628282
# balanced accuracy média: 0.674646283796233
# balanced accuracy desvio: 0.004454060036919463
# +---------------+--------------+
# | Classe        |   Frequência |
# +===============+==============+
# | BENIGN        |            5 |
# +---------------+--------------+
# | TFTP          |            5 |
# +---------------+--------------+
# | DrDoS_SNMP    |            5 |
# +---------------+--------------+
# | DrDoS_DNS     |            5 |
# ...
