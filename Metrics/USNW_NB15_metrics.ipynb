# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate
import time
###########################

# %%
labels_file=pd.read_csv("/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/02-TreatedDataset/NB15_labels.csv",header=None)

# %%
labels_file.value_counts()
# Out:
# Normal            2218764
# Generic            215481
# Exploits            44525
# Fuzzers             24246
# DoS                 16353
# Reconnaissance      13987
# Analysis             2677
# Backdoor             2329
# Shellcode            1511
# Worms                 174
# Name: count, dtype: int64

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-07-04/NB15-LC-s100-a150.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-07-04/NB15-LC-s200-a150.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-07-04/NB15-LC-s300-a150.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-07-04/NB15-LC-s400-a150.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW-NB15/03-Experiments/2024-07-04/NB15-LC-s500-a150.npy', allow_pickle=True).item()

# %%
data1[37520]
# Out:
# {'querying_time': [2.7616374000208452],
#  'classification_time': [2.2120462999446318],
#  'accuracy': [0.9800843815410458],
#  'balanced_accuracy': [0.5392704348743157],
#  'selected_indices': [[783749,
#    1617942,
#    1153675,
#    1605754,
#    1596237,
#    1264498,
#    207821,
#    814175,
#    279125,
#    1497103,
#    933093,
#    207781,
#    1071836,
#    1031678,
#    107993,
#    107978,
#    684728,
#    444528,
#    1100909,
#    261375,
#    814086,
#    695487,
#    1135943,
#    1632284,
#    1358496,
#    1681344,
#    888100,
#    278829,
#    1514018,
#    690541,
#    888190,
#    1467272,
#    804656,
#    687076,
#    365335,
#    1739406,
#    207554,
#    1135650,
#    261641,
#    1170269,
#    1078114,
#    1144528,
#    397561,
#    947726,
#    252165,
#    1209091,
#    664662,
#    683692,
#    1605341,
#    325510,
#    1514417,
#    607974,
#    1049667,
#    658114,
#    1110005,
#    798077,
#    1135489,
#    743571,
#    1514582,
# ...

# %%
querying_time1 = []
classification_time1 = []
for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

print(len(classification_time1[0:76]))
print((classification_time1[0:76]))
#[1.7011432999861427]
# Out:
# 76
# ...

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:76]) + \
                               sum(querying_time2[0:76]) + \
                               sum(querying_time3[0:76]) + \
                               sum(querying_time4[0:76]) + \
                               sum(querying_time5[0:76]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:76])/60 , \
                                    sum(querying_time2[0:76])/60 , \
                                    sum(querying_time3[0:76])/60 , \
                                    sum(querying_time4[0:76])/60 , \
                                    sum(querying_time5[0:76])/60 ])))

print("query time iteration média:",(  data1[37520]['querying_time'][0] + \
                                    data2[37520]['querying_time'][0] + \
                                    data3[37520]['querying_time'][0] + \
                                    data4[37520]['querying_time'][0] + \
                                    data5[37520]['querying_time'][0] )/5)

print("query time iteration desvio:" , np.std(np.array([ data1[37520]['querying_time'][0] , \
                                    data2[37520]['querying_time'][0] , \
                                    data3[37520]['querying_time'][0] , \
                                    data4[37520]['querying_time'][0] , \
                                    data5[37520]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:76]) + \
                                    sum(classification_time2[0:76]) + \
                                    sum(classification_time3[0:76]) + \
                                    sum(classification_time4[0:76]) + \
                                    sum(classification_time5[0:76]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:76])/60 , \
                                    sum(classification_time2[0:76])/60 , \
                                    sum(classification_time3[0:76])/60 , \
                                    sum(classification_time4[0:76])/60 , \
                                    sum(classification_time5[0:76])/60 ])))

print("classification_time iteration média:",(  data1[37520]['classification_time'][0] + \
                                    data2[37520]['classification_time'][0] + \
                                    data3[37520]['classification_time'][0] + \
                                    data4[37520]['classification_time'][0] + \
                                    data5[37520]['classification_time'][0] )/5)

print("classification_time iteration desvio:" , np.std(np.array([ data1[37520]['classification_time'][0] , \
                                    data2[37520]['classification_time'][0] , \
                                    data3[37520]['classification_time'][0] , \
                                    data4[37520]['classification_time'][0] , \
                                    data5[37520]['classification_time'][0] ])))

print("Classes média:",(            data1[37520]['classes_know'][0] + \
                                    data2[37520]['classes_know'][0] + \
                                    data3[37520]['classes_know'][0] + \
                                    data4[37520]['classes_know'][0] + \
                                    data5[37520]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[37520]['classes_know'][0] , \
                                    data2[37520]['classes_know'][0] , \
                                    data3[37520]['classes_know'][0] , \
                                    data4[37520]['classes_know'][0] , \
                                    data5[37520]['classes_know'][0] ])))

print("Acurácia média:",(           data1[37520]['accuracy'][0] + \
                                    data2[37520]['accuracy'][0] + \
                                    data3[37520]['accuracy'][0] + \
                                    data4[37520]['accuracy'][0] + \
                                    data5[37520]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[37520]['accuracy'][0] , \
                                    data2[37520]['accuracy'][0] , \
                                    data3[37520]['accuracy'][0] , \
                                    data4[37520]['accuracy'][0] , \
                                    data5[37520]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[37520]['balanced_accuracy'][0] + \
                                    data2[37520]['balanced_accuracy'][0] + \
                                    data3[37520]['balanced_accuracy'][0] + \
                                    data4[37520]['balanced_accuracy'][0] + \
                                    data5[37520]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[37520]['balanced_accuracy'][0] , \
                                    data2[37520]['balanced_accuracy'][0] , \
                                    data3[37520]['balanced_accuracy'][0] , \
                                    data4[37520]['balanced_accuracy'][0] , \
                                    data5[37520]['balanced_accuracy'][0] ])))


# Definir as classes únicas esperadas
unique_classes = ['Normal', 'Generic', 'Exploits', 'Fuzzers', 'DoS','Reconnaissance','Analysis','Backdoor','Shellcode','Worms']

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[37520]['classes'][0],
    data2[37520]['classes'][0],
    data3[37520]['classes'][0],
    data4[37520]['classes'][0],
    data5[37520]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 3.1493139683292246
# querying_time desvio: 0.5280599296400074
# query time iteration média: 2.2129510999657214
# query time iteration desvio: 0.5634094207953843
# classification_time médio: 0.5860670366541794
# classification_time desvio: 0.13790132357616222
# classification_time iteration média: 0.8748640000354498
# classification_time iteration desvio: 0.18522373001287618
# Classes média: 10.0
# Classes desvio: 0.0
# Acurácia média: 0.9789166879917062
# Acurácia desvio: 0.00020997847792709977
# balanced accuracy média: 0.5187247368188764
# balanced accuracy desvio: 0.003957290899045366
# +----------------+--------------+
# | Classe         |   Frequência |
# +================+==============+
# | Normal         |            5 |
# +----------------+--------------+
# | Generic        |            5 |
# +----------------+--------------+
# | Exploits       |            5 |
# +----------------+--------------+
# | Fuzzers        |            5 |
# ...
