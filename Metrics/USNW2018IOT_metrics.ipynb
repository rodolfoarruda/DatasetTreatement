# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate
import time

###########################

# %%
labels_file=pd.read_csv("/content/drive/MyDrive/IntrusionDetection/UNSW_2018_IoT_Botnet/02-TreatedDataset/UNSW-2018IoTBotnet_labels.csv",header=None)

# %%
labels_file.value_counts()
# Out:
# DoS - UDP                          1032975
# DDoS - TCP                          977380
# DDoS - UDP                          948255
# DoS - TCP                           615800
# Reconnaissance - Service_Scan        73168
# Reconnaissance - OS_Fingerprint      17914
# DoS - HTTP                            1485
# DDoS - HTTP                            989
# Normal - Normal                        477
# Theft - Keylogging                      73
# Theft - Data_Exfiltration                6
# Name: count, dtype: int64

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW_2018_IoT_Botnet/03-Experiments/2024-07-06/UNSW-2018IoTBotnet-LC-s100-a241.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW_2018_IoT_Botnet/03-Experiments/2024-07-06/UNSW-2018IoTBotnet-LC-s200-a241.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW_2018_IoT_Botnet/03-Experiments/2024-07-06/UNSW-2018IoTBotnet-LC-s300-a241.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW_2018_IoT_Botnet/03-Experiments/2024-07-06/UNSW-2018IoTBotnet-LC-s400-a241.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/UNSW_2018_IoT_Botnet/03-Experiments/2024-07-06/UNSW-2018IoTBotnet-LC-s500-a241.npy', allow_pickle=True).item()

# %%
data1[20022]
# Out:
# {'querying_time': [5.389547899831086],
#  'classification_time': [0.4301755998749286],
#  'accuracy': [0.9845387381117017],
#  'balanced_accuracy': [0.8592143182393063],
#  'selected_indices': [[2252986,
#    2530762,
#    777973,
#    885648,
#    777495,
#    244284,
#    475202,
#    2028413,
#    2194534,
#    2535947,
#    2274215,
#    884858,
#    1792241,
#    2416816,
#    1882551,
#    1496284,
#    530175,
#    883769,
#    774984,
#    411908,
#    2338042,
#    322187,
#    125064,
#    2373446,
#    8458,
#    1384161,
#    780900,
#    2166138,
#    471856,
#    2500175,
#    592338,
#    1314511,
#    1549505,
#    1668374,
#    2123101,
#    512813,
#    945811,
#    1413402,
#    1240732,
#    1778731,
#    1760993,
#    1705797,
#    1299528,
#    313126,
#    1021044,
#    1048855,
#    325321,
#    189632,
#    1183783,
#    1863666,
#    260629,
#    582775,
#    189363,
#    1033972,
#    517921,
#    2025419,
#    2227950,
#    311932,
#    327089,
# ...

# %%
querying_time1 = []
classification_time1 = []
for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

print(len(classification_time1[0:41]))
print((classification_time1[0:41]))
#[2.8834947000141256]
# Out:
# 241
# ...

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:41]) + \
                               sum(querying_time2[0:41]) + \
                               sum(querying_time3[0:41]) + \
                               sum(querying_time4[0:41]) + \
                               sum(querying_time5[0:41]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:41])/60 , \
                                    sum(querying_time2[0:41])/60 , \
                                    sum(querying_time3[0:41])/60 , \
                                    sum(querying_time4[0:41])/60 , \
                                    sum(querying_time5[0:41])/60 ])))

print("query time iteration média:",(  data1[20022]['querying_time'][0] + \
                                    data2[20022]['querying_time'][0] + \
                                    data3[20022]['querying_time'][0] + \
                                    data4[20022]['querying_time'][0] + \
                                    data5[20022]['querying_time'][0] )/5)

print("query time iteration desvio:" , np.std(np.array([ data1[20022]['querying_time'][0] , \
                                    data2[20022]['querying_time'][0] , \
                                    data3[20022]['querying_time'][0] , \
                                    data4[20022]['querying_time'][0] , \
                                    data5[20022]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:41]) + \
                                    sum(classification_time2[0:41]) + \
                                    sum(classification_time3[0:41]) + \
                                    sum(classification_time4[0:41]) + \
                                    sum(classification_time5[0:41]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:41])/60 , \
                                    sum(classification_time2[0:41])/60 , \
                                    sum(classification_time3[0:41])/60 , \
                                    sum(classification_time4[0:41])/60 , \
                                    sum(classification_time5[0:41])/60 ])))

print("classification_time iteration média:",(  data1[20022]['classification_time'][0] + \
                                    data2[20022]['classification_time'][0] + \
                                    data3[20022]['classification_time'][0] + \
                                    data4[20022]['classification_time'][0] + \
                                    data5[20022]['classification_time'][0] )/5)

print("classification_time iteration desvio:" , np.std(np.array([ data1[20022]['classification_time'][0] , \
                                    data2[20022]['classification_time'][0] , \
                                    data3[20022]['classification_time'][0] , \
                                    data4[20022]['classification_time'][0] , \
                                    data5[20022]['classification_time'][0] ])))

print("Classes média:",(            data1[20022]['classes_know'][0] + \
                                    data2[20022]['classes_know'][0] + \
                                    data3[20022]['classes_know'][0] + \
                                    data4[20022]['classes_know'][0] + \
                                    data5[20022]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[20022]['classes_know'][0] , \
                                    data2[20022]['classes_know'][0] , \
                                    data3[20022]['classes_know'][0] , \
                                    data4[20022]['classes_know'][0] , \
                                    data5[20022]['classes_know'][0] ])))

print("Acurácia média:",(           data1[20022]['accuracy'][0] + \
                                    data2[20022]['accuracy'][0] + \
                                    data3[20022]['accuracy'][0] + \
                                    data4[20022]['accuracy'][0] + \
                                    data5[20022]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[20022]['accuracy'][0] , \
                                    data2[20022]['accuracy'][0] , \
                                    data3[20022]['accuracy'][0] , \
                                    data4[20022]['accuracy'][0] , \
                                    data5[20022]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[20022]['balanced_accuracy'][0] + \
                                    data2[20022]['balanced_accuracy'][0] + \
                                    data3[20022]['balanced_accuracy'][0] + \
                                    data4[20022]['balanced_accuracy'][0] + \
                                    data5[20022]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[20022]['balanced_accuracy'][0] , \
                                    data2[20022]['balanced_accuracy'][0] , \
                                    data3[20022]['balanced_accuracy'][0] , \
                                    data4[20022]['balanced_accuracy'][0] , \
                                    data5[20022]['balanced_accuracy'][0] ])))


# Definir as classes únicas esperadas
unique_classes = ['DoS - UDP','DDoS - TCP','DDoS - UDP','DoS - TCP', \
                  'Reconnaissance - Service_Scan','Reconnaissance - OS_Fingerprint','DoS - HTTP', \
                  'DDoS - HTTP','Normal - Normal','Theft - Keylogging','Theft - Data_Exfiltration']

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[20022]['classes'][0],
    data2[20022]['classes'][0],
    data3[20022]['classes'][0],
    data4[20022]['classes'][0],
    data5[20022]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 3.6207282500023337
# querying_time desvio: 0.26071753710353524
# query time iteration média: 5.318556140083819
# query time iteration desvio: 0.7372853790288147
# classification_time médio: 0.2967284733336419
# classification_time desvio: 0.05422957866177832
# classification_time iteration média: 0.7560862999875099
# classification_time iteration desvio: 0.13420891903297458
# Classes média: 9.0
# Classes desvio: 0.6324555320336759
# Acurácia média: 0.9990406675892298
# Acurácia desvio: 0.0009219495680584951
# balanced accuracy média: 0.9317663226610444
# balanced accuracy desvio: 0.036213430293614804
# +---------------------------------+--------------+
# | Classe                          |   Frequência |
# +=================================+==============+
# | DoS - UDP                       |            5 |
# +---------------------------------+--------------+
# | DDoS - TCP                      |            5 |
# ...
