# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate
import time
###########################

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/Consolidado/CIC2017-LC-s100-a131.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/Consolidado/CIC2017-LC-s200-a131.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/Consolidado/CIC2017-LC-s300-a131.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/Consolidado/CIC2017-LC-s400-a131.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/Consolidado/CIC2017-LC-s500-a131.npy', allow_pickle=True).item()

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:133]) + \
                               sum(querying_time2[0:133]) + \
                               sum(querying_time3[0:133]) + \
                               sum(querying_time4[0:133]) + \
                               sum(querying_time5[0:133]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:133])/60 , \
                                    sum(querying_time2[0:133])/60 , \
                                    sum(querying_time3[0:133])/60 , \
                                    sum(querying_time4[0:133])/60 , \
                                    sum(querying_time5[0:133])/60 ])))

print("query time iteration média:",(  data1[65530]['querying_time'][0] + \
                                    data2[65530]['querying_time'][0] + \
                                    data3[65530]['querying_time'][0] + \
                                    data4[65530]['querying_time'][0] + \
                                    data5[65530]['querying_time'][0] )/5)

print("query time iteration desvio:" , np.std(np.array([ data1[65530]['querying_time'][0] , \
                                    data2[65530]['querying_time'][0] , \
                                    data3[65530]['querying_time'][0] , \
                                    data4[65530]['querying_time'][0] , \
                                    data5[65530]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:133]) + \
                                    sum(classification_time2[0:133]) + \
                                    sum(classification_time3[0:133]) + \
                                    sum(classification_time4[0:133]) + \
                                    sum(classification_time5[0:133]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:133])/60 , \
                                    sum(classification_time2[0:133])/60 , \
                                    sum(classification_time3[0:133])/60 , \
                                    sum(classification_time4[0:133])/60 , \
                                    sum(classification_time5[0:133])/60 ])))

print("classification_time iteration média:",(  data1[65530]['classification_time'][0] + \
                                    data2[65530]['classification_time'][0] + \
                                    data3[65530]['classification_time'][0] + \
                                    data4[65530]['classification_time'][0] + \
                                    data5[65530]['classification_time'][0] )/5)

print("classification_time iteration desvio:" , np.std(np.array([ data1[65530]['classification_time'][0] , \
                                    data2[65530]['classification_time'][0] , \
                                    data3[65530]['classification_time'][0] , \
                                    data4[65530]['classification_time'][0] , \
                                    data5[65530]['classification_time'][0] ])))

print("Classes média:",(            data1[65530]['classes_know'][0] + \
                                    data2[65530]['classes_know'][0] + \
                                    data3[65530]['classes_know'][0] + \
                                    data4[65530]['classes_know'][0] + \
                                    data5[65530]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[65530]['classes_know'][0] , \
                                    data2[65530]['classes_know'][0] , \
                                    data3[65530]['classes_know'][0] , \
                                    data4[65530]['classes_know'][0] , \
                                    data5[65530]['classes_know'][0] ])))

print("Acurácia média:",(           data1[65530]['accuracy'][0] + \
                                    data2[65530]['accuracy'][0] + \
                                    data3[65530]['accuracy'][0] + \
                                    data4[65530]['accuracy'][0] + \
                                    data5[65530]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[65530]['accuracy'][0] , \
                                    data2[65530]['accuracy'][0] , \
                                    data3[65530]['accuracy'][0] , \
                                    data4[65530]['accuracy'][0] , \
                                    data5[65530]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[65530]['balanced_accuracy'][0] + \
                                    data2[65530]['balanced_accuracy'][0] + \
                                    data3[65530]['balanced_accuracy'][0] + \
                                    data4[65530]['balanced_accuracy'][0] + \
                                    data5[65530]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[65530]['balanced_accuracy'][0] , \
                                    data2[65530]['balanced_accuracy'][0] , \
                                    data3[65530]['balanced_accuracy'][0] , \
                                    data4[65530]['balanced_accuracy'][0] , \
                                    data5[65530]['balanced_accuracy'][0] ])))


# Definir as classes únicas esperadas
unique_classes = ['BENIGN', 'Bot', 'DDoS', 'DoS GoldenEye', 'DoS Hulk',
                  'DoS Slowhttptest', 'DoS slowloris', 'FTP-Patator',
                  'Heartbleed', 'Infiltration', 'PortScan', 'SSH-Patator',
                  'Web Attack � Brute Force', 'Web Attack � Sql Injection',
                  'Web Attack � XSS']

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[65530]['classes'][0],
    data2[65530]['classes'][0],
    data3[65530]['classes'][0],
    data4[65530]['classes'][0],
    data5[65530]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 5.335884589316993
# querying_time desvio: 0.22836015314877636
# query time iteration média: 2.529092869804663
# query time iteration desvio: 0.11589197248698037
# classification_time médio: 2.2415755533375643
# classification_time desvio: 0.11636825586667297
# classification_time iteration média: 1.5792869757908192
# classification_time iteration desvio: 0.07900353785351837
# Classes média: 12.2
# Classes desvio: 0.4
# Acurácia média: 0.9981875196503157
# Acurácia desvio: 0.0005243527827585026
# balanced accuracy média: 0.8053763699686349
# balanced accuracy desvio: 0.013566884487508441
# +----------------------------+--------------+
# | Classe                     |   Frequência |
# +============================+==============+
# | BENIGN                     |            5 |
# +----------------------------+--------------+
# | Bot                        |            5 |
# +----------------------------+--------------+
# ...

# %%
print(f" querying_time 1: {sum(querying_time1[0:133])/60} \
      \n querying_time 2: {sum(querying_time2[0:133])/60} \
      \n querying_time 3: {sum(querying_time3[0:133])/60} \
      \n querying_time 4: {sum(querying_time4[0:133])/60} \
      \n querying_time 5: {sum(querying_time5[0:133])/60}")
print('########################################################')
print(f" classification 1: {sum(classification_time1[0:133])/60} \
      \n classification 2: {sum(classification_time2[0:133])/60} \
      \n classification 3: {sum(classification_time3[0:133])/60} \
      \n classification 4: {sum(classification_time4[0:133])/60} \
      \n classification 5: {sum(classification_time5[0:133])/60}")
print('########################################################')
print(f" querying_time iter 1: {data1[65530]['querying_time'][0]} \
      \n querying_time iter 2: {data2[65530]['querying_time'][0]} \
      \n querying_time iter 3: {data3[65530]['querying_time'][0]} \
      \n querying_time iter 4: {data4[65530]['querying_time'][0]} \
      \n querying_time iter 5: {data5[65530]['querying_time'][0]}")
print('########################################################')
print(f" classification iter 1: {data1[65530]['classification_time'][0]} \
      \n classification iter 2: {data2[65530]['classification_time'][0]} \
      \n classification iter 3: {data3[65530]['classification_time'][0]} \
      \n classification iter 4: {data4[65530]['classification_time'][0]} \
      \n classification iter 5: {data5[65530]['classification_time'][0]}")
print('########################################################')
print(f" Acc iter 1: {data1[65530]['accuracy'][0]} \
      \n Acc iter 2: {data2[65530]['accuracy'][0]} \
      \n Acc iter 3: {data3[65530]['accuracy'][0]} \
      \n Acc iter 4: {data4[65530]['accuracy'][0]} \
      \n Acc iter 5: {data5[65530]['accuracy'][0]}")
print('########################################################')
print(f" Acc bal iter 1: {data1[65530]['balanced_accuracy'][0]} \
      \n Acc bal iter 2: {data2[65530]['balanced_accuracy'][0]} \
      \n Acc bal iter 3: {data3[65530]['balanced_accuracy'][0]} \
      \n Acc bal iter 4: {data4[65530]['balanced_accuracy'][0]} \
      \n Acc bal iter 5: {data5[65530]['balanced_accuracy'][0]}")
# Out:
#  querying_time 1: 5.546087617316759
#  querying_time 2: 5.598747798616144
#  querying_time 3: 5.134288626699223
#  querying_time 4: 5.3871928036169265
#  querying_time 5: 5.013106100335912
# ########################################################
#  classification 1: 2.4411913984831397
#  classification 2: 2.2958876862670876
#  classification 3: 2.155068066599536
#  classification 4: 2.1165542575176612
#  classification 5: 2.1991763578203973
# ########################################################
#  querying_time iter 1: 2.5834455140011414
#  querying_time iter 2: 2.544105988003139
#  querying_time iter 3: 2.659173157007899
#  querying_time iter 4: 2.545913609996205
#  querying_time iter 5: 2.312826080014929
# ########################################################
#  classification iter 1: 1.7020124680002482
#  classification iter 2: 1.6190002930015908
#  classification iter 3: 1.493563780997647
#  classification iter 4: 1.4946798869932536
# ...
