# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###### Main Module
#####
###########################
###### Packages
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
from tabulate import tabulate
import time
###########################

# %%
labels_file=pd.read_csv("/content/drive/MyDrive/IntrusionDetection/CICIDS2017/02-TreatedDataset/CIC2017_labels.csv",header=None)

# %%
labels_file.shape
# Out:
# (2830743, 1)

# %%
labels_file.value_counts()
# Out:
# BENIGN                        2273097
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# FTP-Patator                      7938
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
round((11/2830743)*100,4)
# Out:
# 0.0004

# %%
print((np.unique(y_train)))
# Out:
# ['BENIGN' 'Bot' 'DDoS' 'DoS GoldenEye' 'DoS Hulk' 'DoS Slowhttptest'
#  'DoS slowloris' 'FTP-Patator' 'Heartbleed' 'Infiltration' 'PortScan'
#  'SSH-Patator' 'Web Attack � Brute Force' 'Web Attack � Sql Injection'
#  'Web Attack � XSS']

# %%
data1 = np.load('/content/drive/MyDrive/IntrusionDetection/CICIDS2017/03-Experiments/2024-07-03/CIC2017-LC-s100-a300.npy', allow_pickle=True).item()
data2 = np.load('/content/drive/MyDrive/IntrusionDetection/CICIDS2017/03-Experiments/2024-07-03/CIC2017-LC-s200-a300.npy', allow_pickle=True).item()
data3 = np.load('/content/drive/MyDrive/IntrusionDetection/CICIDS2017/03-Experiments/2024-07-03/CIC2017-LC-s300-a300.npy', allow_pickle=True).item()
data4 = np.load('/content/drive/MyDrive/IntrusionDetection/CICIDS2017/03-Experiments/2024-07-03/CIC2017-LC-s400-a300.npy', allow_pickle=True).item()
data5 = np.load('/content/drive/MyDrive/IntrusionDetection/CICIDS2017/03-Experiments/2024-07-03/CIC2017-LC-s500-a300.npy', allow_pickle=True).item()

# %%
data = data1

# %%
data1[80030]
# Out:
# {'querying_time': [4.5153199339983985],
#  'classification_time': [4.293187076997128],
#  'accuracy': [0.9693598659200223],
#  'balanced_accuracy': [0.7768733674570527],
#  'selected_indices': [[178300,
#    426065,
#    871568,
#    684855,
#    1019425,
#    330249,
#    212458,
#    102353,
#    57673,
#    230130,
#    576526,
#    915133,
#    168790,
#    361520,
#    1130115,
#    341557,
#    865561,
#    701772,
#    389465,
#    507247,
#    979171,
#    251180,
#    663474,
#    379132,
#    1093248,
#    818995,
#    1132586,
#    1058907,
#    205257,
#    590648,
#    272476,
#    692955,
#    461977,
#    600814,
#    656482,
#    650389,
#    600616,
#    50881,
#    471765,
#    574592,
#    726061,
#    386143,
#    906371,
#    898230,
#    786735,
#    670569,
#    227694,
#    52873,
#    562048,
#    760616,
#    610160,
#    295787,
#    365372,
#    718337,
#    775688,
#    62674,
#    7690,
#    792687,
#    34268,
#    48387,
#    238467,
#    251365,
# ...

# %%
data1[66030]

# %%
querying_time1 = []
querying_time2 = []
querying_time3 = []
querying_time4 = []
querying_time5 = []
classification_time1 = []
classification_time2 = []
classification_time3 = []
classification_time4 = []
classification_time5 = []

for key, value in data1.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time1.append(value['querying_time'][0])
        classification_time1.append(value['classification_time'][0])

for key, value in data2.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time2.append(value['querying_time'][0])
        classification_time2.append(value['classification_time'][0])

for key, value in data3.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time3.append(value['querying_time'][0])
        classification_time3.append(value['classification_time'][0])

for key, value in data4.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time4.append(value['querying_time'][0])
        classification_time4.append(value['classification_time'][0])

for key, value in data5.items():
    if isinstance(key, int) and 'balanced_accuracy' in value:
        querying_time5.append(value['querying_time'][0])
        classification_time5.append(value['classification_time'][0])

print("querying_time médio:", (sum(querying_time1[0:133]) + \
                               sum(querying_time2[0:133]) + \
                               sum(querying_time3[0:133]) + \
                               sum(querying_time4[0:133]) + \
                               sum(querying_time5[0:133]) )/5/60)

print("querying_time desvio:" , np.std(np.array([sum(querying_time1[0:133])/60 , \
                                    sum(querying_time2[0:133])/60 , \
                                    sum(querying_time3[0:133])/60 , \
                                    sum(querying_time4[0:133])/60 , \
                                    sum(querying_time5[0:133])/60 ])))

print("query time iteration média:",(  data1[66030]['querying_time'][0] + \
                                    data2[66030]['querying_time'][0] + \
                                    data3[66030]['querying_time'][0] + \
                                    data4[66030]['querying_time'][0] + \
                                    data5[66030]['querying_time'][0] )/5)

print("query time iteration desvio:" , np.std(np.array([ data1[66030]['querying_time'][0] , \
                                    data2[66030]['querying_time'][0] , \
                                    data3[66030]['querying_time'][0] , \
                                    data4[66030]['querying_time'][0] , \
                                    data5[66030]['querying_time'][0] ])))

print("classification_time médio:",( sum(classification_time1[0:133]) + \
                                    sum(classification_time2[0:133]) + \
                                    sum(classification_time3[0:133]) + \
                                    sum(classification_time4[0:133]) + \
                                    sum(classification_time5[0:133]) )/5/60)

print("classification_time desvio:", np.std(np.array([sum(classification_time1[0:133])/60 , \
                                    sum(classification_time2[0:133])/60 , \
                                    sum(classification_time3[0:133])/60 , \
                                    sum(classification_time4[0:133])/60 , \
                                    sum(classification_time5[0:133])/60 ])))

print("classification_time iteration média:",(  data1[66030]['classification_time'][0] + \
                                    data2[66030]['classification_time'][0] + \
                                    data3[66030]['classification_time'][0] + \
                                    data4[66030]['classification_time'][0] + \
                                    data5[66030]['classification_time'][0] )/5)

print("classification_time iteration desvio:" , np.std(np.array([ data1[66030]['classification_time'][0] , \
                                    data2[66030]['classification_time'][0] , \
                                    data3[66030]['classification_time'][0] , \
                                    data4[66030]['classification_time'][0] , \
                                    data5[66030]['classification_time'][0] ])))

print("Classes média:",(            data1[66030]['classes_know'][0] + \
                                    data2[66030]['classes_know'][0] + \
                                    data3[66030]['classes_know'][0] + \
                                    data4[66030]['classes_know'][0] + \
                                    data5[66030]['classes_know'][0] )/5)

print("Classes desvio:" , np.std(np.array([ data1[66030]['classes_know'][0] , \
                                    data2[66030]['classes_know'][0] , \
                                    data3[66030]['classes_know'][0] , \
                                    data4[66030]['classes_know'][0] , \
                                    data5[66030]['classes_know'][0] ])))

print("Acurácia média:",(           data1[66030]['accuracy'][0] + \
                                    data2[66030]['accuracy'][0] + \
                                    data3[66030]['accuracy'][0] + \
                                    data4[66030]['accuracy'][0] + \
                                    data5[66030]['accuracy'][0] )/5)

print("Acurácia desvio:" , np.std(np.array([ data1[66030]['accuracy'][0] , \
                                    data2[66030]['accuracy'][0] , \
                                    data3[66030]['accuracy'][0] , \
                                    data4[66030]['accuracy'][0] , \
                                    data5[66030]['accuracy'][0] ])))

print("balanced accuracy média:",(  data1[66030]['balanced_accuracy'][0] + \
                                    data2[66030]['balanced_accuracy'][0] + \
                                    data3[66030]['balanced_accuracy'][0] + \
                                    data4[66030]['balanced_accuracy'][0] + \
                                    data5[66030]['balanced_accuracy'][0] )/5)

print("balanced accuracy desvio:" , np.std(np.array([ data1[66030]['balanced_accuracy'][0] , \
                                    data2[66030]['balanced_accuracy'][0] , \
                                    data3[66030]['balanced_accuracy'][0] , \
                                    data4[66030]['balanced_accuracy'][0] , \
                                    data5[66030]['balanced_accuracy'][0] ])))


# Definir as classes únicas esperadas
unique_classes = ['BENIGN', 'Bot', 'DDoS', 'DoS GoldenEye', 'DoS Hulk',
                  'DoS Slowhttptest', 'DoS slowloris', 'FTP-Patator',
                  'Heartbleed', 'Infiltration', 'PortScan', 'SSH-Patator',
                  'Web Attack � Brute Force', 'Web Attack � Sql Injection',
                  'Web Attack � XSS']

# Inicializar um dicionário para armazenar as contagens de todas as classes
class_counts_all = {cls: 0 for cls in unique_classes}

# Concatenar todos os vetores em um único array
all_classes = np.concatenate((
    data1[66030]['classes'][0],
    data2[66030]['classes'][0],
    data3[66030]['classes'][0],
    data4[66030]['classes'][0],
    data5[66030]['classes'][0]
))

# Contar as ocorrências de cada classe encontrada
unique_classes_found, class_counts_found = np.unique(all_classes, return_counts=True)

# Atualizar o dicionário com as contagens encontradas
for cls, count in zip(unique_classes_found, class_counts_found):
    if cls in class_counts_all:
        class_counts_all[cls] = count

# Verificar e adicionar zero para classes não encontradas
for cls in unique_classes:
    if cls not in class_counts_all:
        class_counts_all[cls] = 0

# Preparar os dados para a tabela
table_data = []
for cls in unique_classes:
    table_data.append([cls, class_counts_all[cls]])

# Imprimir a tabela usando tabulate
print(tabulate(table_data, headers=['Classe', 'Frequência'], tablefmt='grid'))
# Out:
# querying_time médio: 22.868196135659332
# querying_time desvio: 14.492958459124285
# query time iteration média: 5.224321280012373
# query time iteration desvio: 1.7670945107439004
# classification_time médio: 3.6726747903335006
# classification_time desvio: 1.8670977715822734
# classification_time iteration média: 2.357732460001716
# classification_time iteration desvio: 0.18903794842508226
# Classes média: 12.2
# Classes desvio: 0.4
# Acurácia média: 0.9981974110451552
# Acurácia desvio: 0.0004927875377052843
# balanced accuracy média: 0.8181839289524386
# balanced accuracy desvio: 0.024797702698687616
# +----------------------------+--------------+
# | Classe                     |   Frequência |
# +============================+==============+
# | BENIGN                     |            5 |
# +----------------------------+--------------+
# | Bot                        |            5 |
# +----------------------------+--------------+
# | DDoS                       |            5 |
# ...
